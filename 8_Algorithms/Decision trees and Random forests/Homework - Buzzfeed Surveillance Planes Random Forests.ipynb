# %% [markdown]
# # Finding surveillance planes using random forests
#
# **The story:**
#
# - https://www.buzzfeednews.com/article/peteraldhous/spies-in-the-skies
# - https://www.buzzfeednews.com/article/peteraldhous/hidden-spy-planes
#
# This story, done by Peter Aldhous at Buzzfeed News, involved training a machine learning algorithm to recognize government surveillance planes based on what their flight patterns look like.
#
# **Topics:** Random Forests
#
# **Datasets**
#
# * **feds.csv:** Transponder codes of planes operated by the federal government
# * **planes_features.csv:** various features describing each plane's flight patterns
# * **train.csv:** a labeled dataset of transponder codes and whether each plane is a surveillance plane or not
#     - The `label` column was originally `class`, but I renamed it because pandas freaks out a bit with a column named `class`
#     - This was created by Buzzfeed `feds.csv`
# * **data dictionary:** You can find the data dictionary published with their analysis [here](https://buzzfeednews.github.io/2016-04-federal-surveillance-planes/analysis.html)
# * **a few other files**
#
# ## What's the goal?
#
# The FBI and Department of Homeland Security operate many planes that are not directly labeled as belonging to the government. If we can uncover these planes, we have a better idea of the surveillance activities they are undertaking.

# %% [markdown]
# ## Imports
#
# Also set a large number of maximum columns.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
pd.set_option("display.max_columns",100)

# %% [markdown]
# # Read in our data
#
# Almost all classification problems start with a set of labeled features. In this case, the features are in one CSV file and the labels are in another. **Read both files in and merge them on `adshex`, the transpoder code.**

# %%
features=pd.read_csv("planes_features.csv")

# %%
features.shape
# Out:
# (19799, 33)

# %%
features.columns
# Out:
# Index(['adshex', 'duration1', 'duration2', 'duration3', 'duration4',
#        'duration5', 'boxes1', 'boxes2', 'boxes3', 'boxes4', 'boxes5', 'speed1',
#        'speed2', 'speed3', 'speed4', 'speed5', 'altitude1', 'altitude2',
#        'altitude3', 'altitude4', 'altitude5', 'steer1', 'steer2', 'steer3',
#        'steer4', 'steer5', 'steer6', 'steer7', 'steer8', 'flights', 'squawk_1',
#        'observations', 'type'],
#       dtype='object')

# %%
features.head()
# Out:
#    adshex  duration1  duration2  duration3  duration4  duration5    boxes1  \
# 0       A   0.120253   0.075949   0.183544   0.335443   0.284810  0.088608
# 1  A00000   0.211735   0.155612   0.181122   0.198980   0.252551  0.204082
# 2  A00002   0.517241   0.103448   0.103448   0.103448   0.172414  0.862069
# 3  A00008   0.125000   0.041667   0.208333   0.166667   0.458333  0.125000
# 4  A0001E   0.100000   0.200000   0.200000   0.400000   0.100000  0.100000
#
#      boxes2    boxes3    boxes4    boxes5    speed1    speed2    speed3  \
# 0  0.044304  0.069620  0.120253  0.677215  0.021824  0.020550  0.062330
# 1  0.183673  0.168367  0.173469  0.267857  0.107348  0.143410  0.208139
# 2  0.137931  0.000000  0.000000  0.000000  0.990792  0.000921  0.000000
# 3  0.083333  0.125000  0.166667  0.500000  0.187960  0.278952  0.221048
# 4  0.000000  0.100000  0.400000  0.400000  0.007937  0.026984  0.084127
#
#      speed4    speed5  altitude1  altitude2  altitude3  altitude4  altitude5  \
# 0  0.100713  0.794582   0.042374   0.060971   0.066831   0.106403   0.723421
# 1  0.177013  0.364090   0.177318   0.114457   0.129648   0.197694   0.380882
# 2  0.000000  0.008287   0.599448   0.400552   0.000000   0.000000   0.000000
# 3  0.190257  0.121783   0.014706   0.053309   0.149816   0.279871   0.502298
# 4  0.179365  0.701587   0.041270   0.085714   0.039683   0.111111   0.722222
#
#      steer1    steer2    steer3    steer4    steer5    steer6    steer7  \
# 0  0.020211  0.048913  0.270550  0.344090  0.097317  0.186651  0.011379
# 1  0.034976  0.048127  0.240732  0.356314  0.116116  0.159325  0.012828
# 2  0.105893  0.090239  0.174954  0.244015  0.034070  0.202578  0.021179
# 3  0.029871  0.044118  0.202665  0.380515  0.094669  0.182904  0.014706
# 4  0.019048  0.049206  0.249206  0.326984  0.112698  0.206349  0.012698
#
#      steer8  flights  squawk_1  observations  type
# 0  0.009426      158         0         11776  GRND
# 1  0.013628      392         0         52465  TBM7
# 2  0.068140       29         0          1086  SHIP
# 3  0.020221       24         0          2176  PA46
# 4  0.011111       10      1135           630  C56X

# %%
labels=pd.read_csv("train.csv")

# %%
labels.columns
# Out:
# Index(['adshex', 'label'], dtype='object')

# %%
labels.head()
# Out:
#    adshex    label
# 0  A00C4B  surveil
# 1  A0AB21  surveil
# 2  A0AE77  surveil
# 3  A0AE7C  surveil
# 4  A0C462  surveil

# %%
df=features.merge(labels, on="adshex", how="left")

# %%
df.shape
# Out:
# (19799, 34)

# %% [markdown]
# ### No wait, merge them again!
#
# We have features for about 20,000 planes and labels for about 600 planes. When you merge, the planes you have features for but not labels for will disappear.
#
# We want to keep those in the dataframe so we can play detective with them later, and try to find surveillance planes using the features. When you merge, you should use `how='left'` or `how='right'` to keep unmatched columns from the left (or right) dataframe.

# %% [markdown]
# Confirm you have 19,799 rows and 34 columns.

# %%
#Yes

# %% [markdown]
# # Cleaning up our data
#
# ## Number-izing our labels
#
# Each row is a plane, and it's marked as either a surveillance plane or not. How many do we have in each category?

# %%
df.label.value_counts()
# Out:
# other      500
# surveil     97
# Name: label, dtype: int64

# %% [markdown]
# How do you feel about that split?
#
# **Prepare this column for machine learning.** What's wrong with it as `"surveil"` and `"other"`? Add a new column that we can use for classification.

# %%
df.label=df.label.replace({
    "other":0,
    "surveil":1
})

# %%
#Re-checking the variable to make sure it is encoded correctly
df.label.value_counts()
# Out:
# 0.0    500
# 1.0     97
# Name: label, dtype: int64

# %%
df.head()
# Out:
#    adshex  duration1  duration2  duration3  duration4  duration5    boxes1  \
# 0       A   0.120253   0.075949   0.183544   0.335443   0.284810  0.088608
# 1  A00000   0.211735   0.155612   0.181122   0.198980   0.252551  0.204082
# 2  A00002   0.517241   0.103448   0.103448   0.103448   0.172414  0.862069
# 3  A00008   0.125000   0.041667   0.208333   0.166667   0.458333  0.125000
# 4  A0001E   0.100000   0.200000   0.200000   0.400000   0.100000  0.100000
#
#      boxes2    boxes3    boxes4    boxes5    speed1    speed2    speed3  \
# 0  0.044304  0.069620  0.120253  0.677215  0.021824  0.020550  0.062330
# 1  0.183673  0.168367  0.173469  0.267857  0.107348  0.143410  0.208139
# 2  0.137931  0.000000  0.000000  0.000000  0.990792  0.000921  0.000000
# 3  0.083333  0.125000  0.166667  0.500000  0.187960  0.278952  0.221048
# 4  0.000000  0.100000  0.400000  0.400000  0.007937  0.026984  0.084127
#
#      speed4    speed5  altitude1  altitude2  altitude3  altitude4  altitude5  \
# 0  0.100713  0.794582   0.042374   0.060971   0.066831   0.106403   0.723421
# 1  0.177013  0.364090   0.177318   0.114457   0.129648   0.197694   0.380882
# 2  0.000000  0.008287   0.599448   0.400552   0.000000   0.000000   0.000000
# 3  0.190257  0.121783   0.014706   0.053309   0.149816   0.279871   0.502298
# 4  0.179365  0.701587   0.041270   0.085714   0.039683   0.111111   0.722222
#
#      steer1    steer2    steer3    steer4    steer5    steer6    steer7  \
# 0  0.020211  0.048913  0.270550  0.344090  0.097317  0.186651  0.011379
# 1  0.034976  0.048127  0.240732  0.356314  0.116116  0.159325  0.012828
# 2  0.105893  0.090239  0.174954  0.244015  0.034070  0.202578  0.021179
# 3  0.029871  0.044118  0.202665  0.380515  0.094669  0.182904  0.014706
# 4  0.019048  0.049206  0.249206  0.326984  0.112698  0.206349  0.012698
#
#      steer8  flights  squawk_1  observations  type  label
# 0  0.009426      158         0         11776  GRND    NaN
# 1  0.013628      392         0         52465  TBM7    NaN
# 2  0.068140       29         0          1086  SHIP    0.0
# 3  0.020221       24         0          2176  PA46    NaN
# 4  0.011111       10      1135           630  C56X    NaN

# %% [markdown]
# ## Categorical variables
#
# Do we have any variables that count as categories? Yes, we do! ...but how many different categories does it have?
#
# * **Tip:** You can use `.unique()` or `.value_counts()` to count unique items, depending on what you're looking for

# %%
df.type.value_counts()
# Out:
# unknown    2528
# C172       1014
# SR22        799
# BE36        699
# C182        693
# PC12        630
# BE20        465
# PA46        438
# P28A        415
# BE9L        408
# C208        395
# BE58        387
# M20P        335
# B350        333
# P46T        285
# C82S        235
# T206        234
# C421        225
# BE35        222
# DA40        214
# BE55        204
# TBM8        204
# B407        202
# C340        199
# COL4        196
# M20T        180
# C414        177
# AS50        175
# EA50        167
# PA32        161
#            ...
# BE45          1
# SVNH          1
# AT75          1
# DHC1          1
# CV64          1
# VTUR          1
# MIMU          1
# PULS          1
# L90           1
# GYRO          1
# TAMP          1
# S108          1
# EGRT          1
# M20J          1
# SYMP          1
# ONEX          1
# J2            1
# B212          1
# A4            1
# COL           1
# B427          1
# B58           1
# T850          1
# MC90          1
# E545          1
# TVL4          1
# DE55          1
# SF50          1
# TAGO          1
# BE80          1
# Name: type, Length: 455, dtype: int64

# %% [markdown]
# Most of those types of plane only have one appearance, which means they wouldn't be very helpful identifiers in the final analysis. For example, if I only see one GLF5 and it's a surveillance plane, does that mean the next one I see is probably a surveillance plane? With such a small sample size, I have no idea!
#
# We have a few options
#
# 1. Create a very large set of dummy variables out of all 133 types of planes
# 2. Create `0`/`1` columns for common plane types and ignore the less common ones -  C182, T206, SR22
# 3. Interview someone who knows something about planes and put these into a few broader categories
# 4. Keep them as one column, just turn them into numbers - it doesn't make sense in terms of order, but if one or two plane types are very indicative of a surveillance plane the forest might pick it up
#
# Oddly enough, **the last one is a common approach.** Let's use it!
#
# If you want to convert a list of categories into numbers, an easy way is to use the `Categorical` data type.

# %%
df.type = df.type.astype('category')
df.type.head()
# Out:
# 0    GRND
# 1    TBM7
# 2    SHIP
# 3    PA46
# 4    C56X
# Name: type, dtype: category
# Categories (455, object): [208, A109, A119, A139, ..., WW24, XL2, ZZZZ, unknown]

# %% [markdown]
# It looks like a normal bunch of strings, but pandas is secretly using a number for each one! You can find the number with `.cat.codes`.
#
# **Use `df.type.cat.codes` to make a new columns called `type_code`.**

# %%
df["type_code"]=df.type.cat.codes

# %%
df["type_code"].value_counts()
# Out:
# 454    2528
# 88     1014
# 406     799
# 54      699
# 91      693
# 356     630
# 48      465
# 350     438
# 323     415
# 69      408
# 97      395
# 60      387
# 300     335
# 33      333
# 333     285
# 133     235
# 417     234
# 115     225
# 53      222
# 163     214
# 432     204
# 58      204
# 35      202
# 110     199
# 148     196
# 301     180
# 114     177
# 18      175
# 191     167
# 347     161
#        ...
# 123       1
# 187       1
# 361       1
# 203       1
# 450       1
# 434       1
# 299       1
# 402       1
# 370       1
# 363       1
# 282       1
# 250       1
# 234       1
# 307       1
# 393       1
# 409       1
# 425       1
# 26        1
# 42        1
# 20        1
# 4         1
# 435       1
# 419       1
# 403       1
# 138       1
# 371       1
# 202       1
# 339       1
# 218       1
# 0         1
# Name: type_code, Length: 455, dtype: int64

# %% [markdown]
# We'll use `type_code` for machine learning since sklearn needs a number, and `type` for reading since we like text.

# %% [markdown]
# # Building our classifier
#
# When we're about to classify, we usually just drop our target column to build our inputs and outputs:
#
# ```python
# X = train_df.drop(column='column_you_are_predicting')
# y = train_df.column_you_are_predicting
# ```
#
# This time is a little different. First, we have unlabeled data in there! Use `.dropna()` to filter your training data so we only have labeled data.
#
# Confirm `train_df` has 597 rows and 35 columns.

# %% [markdown]
# We also have a few extra columns that we aren't using for classification (like the text version of the type column and the transponder code). It's fine to drop multiple columns here that you aren't using, just a little bit messier. You also have to make sure you're dropping all the right ones.
#
# Do a `.head()` to double-check all of the columns you need to drop when creating your `X`.

# %%
train_df=df.dropna(subset=["label"])

# %%
train_df.label.value_counts()
# Out:
# 0.0    500
# 1.0     97
# Name: label, dtype: int64

# %%
#Note: Non-surveillance planes are under-represented in our dataset, as a result of which our model might be over-fitted to 
# detect the types of planes that are marked as surveillance planes in our dataset. Ideally, you would want a close to 50-50 split of
# the 0 and 1 outcomes.

# %% [markdown]
# ### Create your `X` and `y`.
#
# When you do `train_df.drop`, you'll want to remove more than just your `0`/`1` surveillance label. What other columns do you not want to use as input? Maybe some categories you converted into codes?

# %%
X=train_df.drop(columns=["label","adshex","type"])
y=train_df["label"]

# %% [markdown]
# Triple-check that `X` is a list of numeric features and and `y` is a numeric label.

# %%
X.sample(5)
# Out:
#        duration1  duration2  duration3  duration4  duration5    boxes1  \
# 19158   0.470588   0.117647   0.117647   0.058824   0.235294  0.588235
# 7587    0.087719   0.087719   0.157895   0.298246   0.368421  0.070175
# 10010   0.000000   0.000000   0.000000   0.666667   0.333333  0.000000
# 2634    0.294118   0.176471   0.352941   0.176471   0.000000  0.470588
# 8408    0.000000   0.500000   0.250000   0.250000   0.000000  0.250000
#
#          boxes2    boxes3    boxes4    boxes5    speed1    speed2    speed3  \
# 19158  0.235294  0.176471  0.000000  0.000000  0.849986  0.107900  0.041013
# 7587   0.052632  0.140351  0.280702  0.456140  0.010362  0.018580  0.159982
# 10010  0.000000  0.000000  0.333333  0.666667  0.054419  0.052093  0.068372
# 2634   0.470588  0.058824  0.000000  0.000000  0.276002  0.078443  0.571761
# 8408   0.250000  0.500000  0.000000  0.000000  0.458156  0.527660  0.014184
#
#          speed4    speed5  altitude1  altitude2  altitude3  altitude4  \
# 19158  0.000826  0.000275   0.011836   0.031379   0.218277   0.738508
# 7587   0.398660  0.412416   0.048236   0.083162   0.085753   0.171416
# 10010  0.082326  0.742791   0.123721   0.161395   0.138605   0.098140
# 2634   0.073794  0.000000   0.847182   0.124927   0.016270   0.011621
# 8408   0.000000  0.000000   0.209929   0.672340   0.117730   0.000000
#
#        altitude5    steer1    steer2    steer3    steer4    steer5    steer6  \
# 19158   0.000000  0.088632  0.141206  0.132673  0.129370  0.019268  0.308560
# 7587    0.611434  0.005270  0.010808  0.222331  0.529611  0.163109  0.058955
# 10010   0.478140  0.019070  0.028372  0.261860  0.436279  0.093023  0.141860
# 2634    0.000000  0.049390  0.056363  0.241720  0.248693  0.118536  0.209762
# 8408    0.000000  0.005674  0.011348  0.364539  0.236879  0.158865  0.219858
#
#          steer7    steer8  flights  squawk_1  observations  type_code
# 19158  0.093587  0.036334       17       263          3633         95
# 7587   0.002590  0.002590       57         0         11195        110
# 10010  0.007442  0.003256        9      4720          2150        454
# 2634   0.030215  0.020337       17         0          1721        382
# 8408   0.000000  0.000000        4      4360           705        454

# %%
y.sample(5)
# Out:
# 4988     1.0
# 6694     0.0
# 13614    0.0
# 5848     1.0
# 14596    0.0
# Name: label, dtype: float64

# %% [markdown]
# ### Split into test and train datasets
#
# We could be nice and lazy and use all our data for training, but it just isn't right! Taking a test using the exact same questions you studied is just cheating. Split your data into test and train.
#
# * **Tip:** Don't do this manually! There's a method for it in sklearn

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, random_state=42)

# %%
# Looking at the distribution of our test and train datasets
X_train.shape
# Out:
# (447, 32)

# %%
y_train.shape
# Out:
# (447,)

# %%
X_test.shape
# Out:
# (150, 32)

# %%
y_test.shape
# Out:
# (150,)

# %%
y_train.value_counts(normalize=True)
# Out:
# 0.0    0.829978
# 1.0    0.170022
# Name: label, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0.0    0.86
# 1.0    0.14
# Name: label, dtype: float64

# %%
# Our train and test datasets are identical - i.e., the distribution of surveillance and non-surveillance planes in similar.

# %% [markdown]
# # Classify using a logistic classifier
#
# ## Train your classifier
#
# Build a `LogisticRegression` and fit it to your data, making sure you're training using only `X_train` and `y_train`.
#
# * **Tip:** You'll want to give `LogisticRegression` an extra argument of `max_iter=4000` - it means "work a little harder than you expect," because otherwise it won't find an answer (by default it only has a `max_iter` of 100)

# %%
from sklearn.linear_model.logistic import LogisticRegression
model=LogisticRegression(C=1e9, solver="lbfgs",max_iter=4000)
result=model.fit(X_train,y_train)

# %%
pd.DataFrame({
    "features":X_train.columns,
    "coefficients":np.exp(result.coef_[0])
}).sort_values(by="coefficients", ascending=False)
# Out:
#         features  coefficients
# 17     altitude3      6.224278
# 10        speed1      5.303217
# 5         boxes1      4.692373
# 21        steer2      4.663586
# 6         boxes2      3.220481
# 0      duration1      2.754534
# 20        steer1      2.544735
# 18     altitude4      1.832735
# 11        speed2      1.716659
# 27        steer8      1.045356
# 1      duration2      1.033070
# 26        steer7      1.026840
# 29      squawk_1      1.000603
# 30  observations      1.000019
# 31     type_code      0.998520
# 28       flights      0.994035
# 4      duration5      0.827655
# 22        steer3      0.792161
# 7         boxes3      0.707985
# 12        speed3      0.453404
# 25        steer6      0.448719
# 16     altitude2      0.417652
# 24        steer5      0.394455
# 2      duration3      0.364201
# 8         boxes4      0.286960
# 19     altitude5      0.239423
# 14        speed5      0.212493
# 3      duration4      0.203831
# 13        speed4      0.199336
# 15     altitude1      0.153275
# 23        steer4      0.081278
# 9         boxes5      0.056948

# %% [markdown]
# ## Examine the coefficients
#
# What does it mean? What features is the classifier using? Do you care about the odds ratio? **What is even the point of this `LogisticRegression` thing?**

# %%
# A logistic regression uses the features that are specified by us. Therefore, the classifier is using the 27 features that 
# we have inputted as the X variable.

# The model shows that the altitude at which the plane is flying at is the strongest predictor of wwhether it is a surveillance
# plane or not.

# The odds-ratio is interpreted as: "for every 1 unit increase in altitude, there is a 6 unit increase in the LIKELIHOOD
# of the plane being a surveillance plane (i.e., y being 1).

# %% [markdown]
# ## How well does our classifier perform?
#
# Let's take a look at the confusion matrix to see how well this classifier finds surveillance planes.
#
# ```python
# from sklearn.metrics import confusion_matrix
#
# y_true = y_test
# y_pred = clf.predict(X_test)
# matrix = confusion_matrix(y_true, y_pred)
#
# label_names = pd.Series(['not surveil', 'surveil'])
# pd.DataFrame(matrix,
#      columns='Predicted ' + label_names,
#      index='Is ' + label_names)
# ```
#
# Notice we're using `y_test` and `X_test`, not the full dataset.

# %%
# In order to test our model, we need to apply it to our test dataset. 

#The variable predictions will give us a 0 or 1 value for each observations based on what the model has detected.
predictions=model.predict(X_test)

# The 2-D array probabilities will give us the probability percentage of each value being 0 or 1. 
probabilities=model.predict_proba(X_test)

# Saving these as dataframes to enable a merge
predict_df=pd.DataFrame(predictions).reset_index(drop=True)

predict_df=predict_df.rename(columns={
    0:"predicted_outcome"
})

prob_df=pd.DataFrame(probabilities).add_prefix("prob")

test_results=predict_df.join(prob_df)

test_results.predicted_outcome.value_counts(normalize=True)
# Out:
# 0.0    0.88
# 1.0    0.12
# Name: predicted_outcome, dtype: float64

# %% [markdown]
# Why do we use `y_test` and `X_test` instead of the full dataset?

# %%
# To avoid over-fitting our model

# Generating a confusion matrix

from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(y_test,predictions)

pd.DataFrame(matrix, index=["Actual_0","Actual_1"], columns=["Predicted_0", "Predicted_1"])

total=125+4+7+14

# Accuracy: 
print(f"The accuracy rate is {(125+14)/total *100: .2f}%.")

# Error rate:
print(f"The error rate is {(4+7)/total *100: .2f}%.")

# Specificity (negatives):
print (f"The specificity rate is {125/(125+4)*100: .2f}%.")

# Sensitivity/Recall (positives):
print(f"The sensitivity rate is {14/(14+7)*100: .2f}%.")
# Out:
# The accuracy rate is  92.67%.
# The error rate is  7.33%.
# The specificity rate is  96.90%.
# The sensitivity rate is  66.67%.

# %% [markdown]
# # Classify using a decision tree
#
# Now we'll use a decision tree. This is how you make one:
#
# ```python
# from sklearn.tree import DecisionTreeClassifier
#
# clf = DecisionTreeClassifier()
# ```
#
# But it's up to you to teach it what spy planes look like using your training data.
#
# If we use `max_depth=` to limit the depth of the tree, it will help us visualize it. For example, `max_depth=5` will only allow the tree to make five decisions.
#
# Make a decision tree and fit it to your data. Use a `max_depth=` of something between 2 to 5.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(max_depth=3)
tree_results=model.fit(X_train, y_train)
tree_predictions=tree_results.predict(X_test)
tree_probabilities=tree_results.predict_proba(X_test)

# %%
tree_predictions_df=pd.DataFrame(tree_predictions)
tree_predictions_df=tree_predictions_df.rename(columns={
    0:"predicted_outcome"
})
tree_prob_df=pd.DataFrame(tree_probabilities).add_prefix("prob_")

tree_predictions_df.join(tree_prob_df)
# Out:
#      predicted_outcome    prob_0    prob_1
# 0                  0.0  0.987692  0.012308
# 1                  0.0  0.987692  0.012308
# 2                  1.0  0.016949  0.983051
# 3                  0.0  0.987692  0.012308
# 4                  0.0  0.987692  0.012308
# 5                  0.0  0.829787  0.170213
# 6                  0.0  0.987692  0.012308
# 7                  0.0  0.987692  0.012308
# 8                  0.0  0.987692  0.012308
# 9                  0.0  0.987692  0.012308
# 10                 0.0  0.987692  0.012308
# 11                 0.0  0.987692  0.012308
# 12                 0.0  0.987692  0.012308
# 13                 1.0  0.016949  0.983051
# 14                 0.0  0.987692  0.012308
# 15                 0.0  0.987692  0.012308
# 16                 0.0  0.987692  0.012308
# 17                 0.0  0.987692  0.012308
# 18                 0.0  0.987692  0.012308
# 19                 0.0  0.987692  0.012308
# 20                 0.0  0.987692  0.012308
# 21                 0.0  0.987692  0.012308
# 22                 0.0  0.829787  0.170213
# 23                 0.0  0.987692  0.012308
# 24                 0.0  0.987692  0.012308
# 25                 0.0  1.000000  0.000000
# 26                 0.0  0.987692  0.012308
# 27                 0.0  0.987692  0.012308
# 28                 0.0  0.987692  0.012308
# 29                 1.0  0.016949  0.983051
# ..                 ...       ...       ...
# 120                0.0  0.987692  0.012308
# 121                0.0  0.987692  0.012308
# 122                0.0  0.987692  0.012308
# 123                0.0  0.987692  0.012308
# 124                0.0  0.987692  0.012308
# 125                0.0  0.987692  0.012308
# 126                0.0  0.987692  0.012308
# 127                0.0  1.000000  0.000000
# 128                1.0  0.016949  0.983051
# 129                0.0  0.987692  0.012308
# 130                0.0  0.987692  0.012308
# 131                0.0  0.829787  0.170213
# 132                0.0  0.987692  0.012308
# 133                0.0  0.987692  0.012308
# 134                0.0  0.987692  0.012308
# 135                0.0  0.987692  0.012308
# 136                0.0  0.829787  0.170213
# 137                0.0  0.987692  0.012308
# 138                0.0  0.987692  0.012308
# 139                0.0  0.987692  0.012308
# 140                1.0  0.016949  0.983051
# 141                0.0  0.829787  0.170213
# 142                0.0  0.987692  0.012308
# 143                0.0  1.000000  0.000000
# 144                1.0  0.016949  0.983051
# 145                0.0  0.987692  0.012308
# 146                0.0  0.987692  0.012308
# 147                0.0  0.987692  0.012308
# 148                0.0  1.000000  0.000000
# 149                0.0  0.987692  0.012308
#
# [150 rows x 3 columns]

# %% [markdown]
# ## What are the important features?
#
# This code is slightly different than feature importance for logistic regression. It looks like this:
#
# ```python
# feature_names = X.columns
# importances = clf.feature_importances_
#
# pd.DataFrame({
#     'feature': feature_names,
#     'feature importance': importances,
# }).sort_values(by='feature importance', ascending=False)
# ```

# %%
pd.DataFrame({
    "feature_names":X.columns,
    "importances":model.feature_importances_
}).sort_values(by="importances", ascending=False)
# Out:
#    feature_names  importances
# 21        steer2     0.889744
# 3      duration4     0.036168
# 11        speed2     0.034611
# 0      duration1     0.020474
# 10        speed1     0.019003
# 24        steer5     0.000000
# 20        steer1     0.000000
# 22        steer3     0.000000
# 23        steer4     0.000000
# 25        steer6     0.000000
# 18     altitude4     0.000000
# 26        steer7     0.000000
# 27        steer8     0.000000
# 28       flights     0.000000
# 29      squawk_1     0.000000
# 30  observations     0.000000
# 19     altitude5     0.000000
# 16     altitude2     0.000000
# 17     altitude3     0.000000
# 1      duration2     0.000000
# 15     altitude1     0.000000
# 14        speed5     0.000000
# 13        speed4     0.000000
# 12        speed3     0.000000
# 9         boxes5     0.000000
# 8         boxes4     0.000000
# 7         boxes3     0.000000
# 6         boxes2     0.000000
# 5         boxes1     0.000000
# 4      duration5     0.000000
# 2      duration3     0.000000
# 31     type_code     0.000000

# %% [markdown]
# ### Understanding the output
#
# **Why is the feature importance difference than for logistic regression?**
#
# Also, if you don't specify a `max_depth`, that's a LOT of zeroes! It doesn't even use most of the features! **Why not?**

# %%
# The two models look at different metrics. A logistic regression model looks at the odds ratios of the X and Y variables 
# relative to the reference variable whereas decision trees look at the Gini index which measures the probabilities of 
# the X and Y variables occuring in different combinations.

# The features are ranked in the order of the number of times they occur in the tree. Features with 0 don't consitute the tree.
# It doesn't mean they don't have any association with y. They just have a weaker association as compared to the variables 
# appearing above them.

# %% [markdown]
# ## How well does the tree perform?
#
# Display another confusion matrix with your new classifier.

# %%
matrix=confusion_matrix(y_test, tree_predictions)

matrix_df=pd.DataFrame(matrix, index=["Actual_0","Actual_1"], columns=["Predicted_0","Predicted_1"])

#metrics
total=122+7+7+14

print(f"The accuracy of the model is {(122+14)/total*100: .2f}%.")

print(f"The error pct is {(7+7)/total*100:.2f}%.")

print(f"The specificity pct is {122/(122+7)*100: .2f}%.")

print(f"The sensitivity/recall pct is {14/(14+7)*100: .2f}%.")

print("---------------------------------------")
print(matrix_df)
# Out:
# The accuracy of the model is  90.67%.
# The error pct is 9.33%.
# The specificity pct is  94.57%.
# The sensitivity/recall pct is  66.67%.
# ---------------------------------------
#           Predicted_0  Predicted_1
# Actual_0          125            4
# Actual_1            9           12

# %% [markdown]
# ## Visualize the tree
#
# You can use this code to visualize the tree. You might need to `brew install graphviz` and `pip install graphviz`.
#
# ```python
# from sklearn import tree
# import graphviz
#
# label_names = ['not surveillance', 'surveillance']
# feature_names = X.columns
#
# dot_data = tree.export_graphviz(clf,
#                     feature_names=feature_names,
#                     filled=True,
#                     class_names=label_names)
# graph = graphviz.Source(dot_data)
# graph
# ```
#
# * **Tip:** You'll probably need to scroll sideways a bit

# %%
from sklearn import tree
import graphviz

label_names = ['not surveillance', 'surveillance']
feature_names = X.columns

dot_data = tree.export_graphviz(model,
                    feature_names=feature_names,  
                    filled=True,
                    class_names=label_names)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# # One more classifier: Random forest
#
# ## Build and train your classifier
#
# We can build a random forest classifier like this:
#
# ```python
# from sklearn.ensemble import RandomForestClassifier
# clf = RandomForestClassifier()
# ```
#
# But you're in charge of fitting it to your training data!
#
# * **Tip:** You can also set `max_depth` here, but you won't be able to visualize the result.
# * **Tip:** Increase `n_estimators` to 100 to make a better classifier.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest_model=RandomForestClassifier(n_estimators=100, max_depth=5)
results=forest_model.fit(X_train, y_train)

# %% [markdown]
# ## What are the important features?

# %%
pd.DataFrame({
"name": X_train.columns,
"pct_contribution": results.feature_importances_
}).sort_values(by="pct_contribution", ascending=False)
# Out:
#             name  pct_contribution
# 21        steer2          0.204562
# 20        steer1          0.173809
# 24        steer5          0.077085
# 29      squawk_1          0.072564
# 17     altitude3          0.053257
# 25        steer6          0.040064
# 15     altitude1          0.038501
# 23        steer4          0.033755
# 10        speed1          0.029258
# 9         boxes5          0.021423
# 5         boxes1          0.019713
# 3      duration4          0.017699
# 0      duration1          0.017576
# 30  observations          0.017494
# 19     altitude5          0.014858
# 12        speed3          0.014320
# 13        speed4          0.013194
# 11        speed2          0.013076
# 6         boxes2          0.012667
# 31     type_code          0.012169
# 27        steer8          0.011790
# 26        steer7          0.011588
# 28       flights          0.011370
# 18     altitude4          0.010931
# 4      duration5          0.009533
# 8         boxes4          0.008963
# 2      duration3          0.008447
# 7         boxes3          0.008209
# 14        speed5          0.006999
# 22        steer3          0.006220
# 1      duration2          0.004682
# 16     altitude2          0.004221

# %%
predictions=forest_model.predict(X_test)
matrix=confusion_matrix(y_test, predictions)
matrix=pd.DataFrame(matrix, index=["Actual_0","Actual_1"], columns=["Predicted_0","Predicted_1"])

total=127+2+5+16

#Accuracy
print(f"The accuracy is {(127+16)/total*100:.2f}%.")

#Error rate
print(f"The error pct is {(2+5)/total*100:.2f}%.")

#Specificity (errors)
print(f"The specificity pct is {127/(127+2)*100: .2f}%.")

#Sensitivity/recall (correct predictions)
print(f"The sensitivity/recall pct is {16/(16+5)*100: .2f}%.")

print("---------------------------------------")

print(matrix)
# Out:
# The accuracy is 95.33%.
# The error pct is 4.67%.
# The specificity pct is  98.45%.
# The sensitivity/recall pct is  76.19%.
# ---------------------------------------
#           Predicted_0  Predicted_1
# Actual_0          127            2
# Actual_1            5           16

# %% [markdown]
# ### Understanding the output
#
# What is a random forest, and **why is the feature importance difference than for the decision tree?** Isn't a random forest just like a decision tree or something?

# %%
# A random forest is a collection of decision trees. The feature importance is different because with a random forest, 
## the features are identified by aggregating the outputs of individual trees whereas in a decision tree model, we are relying
## on the estimate of one tree.

# Random forests tend to be more accurate, particularly for large datasets, a sit is based on the theory of central tendency, i.e.,
## the larger the sample, the more accurate the estimate is to the true value.

# %% [markdown]
# ## How well does it perform?

# %%
## The random forest has an accuracy of 95.33%, ~5% higher than the accuracy of the decision tree (~90.67%). 
## The forest performs better than the tree on measures of specificity and sensitivity, and is therefore, the better model 
## amongst the three models.

# %% [markdown]
# ### How confident do you feel in the model?

# %%
# Same as above

# %% [markdown]
# # Actually finding spy planes
#
# Now let's try ot actually find our spy planes
#
# ## Retrain our model
#
# When we did test/train split, we trained our model with only a subset of our data, so we could test with the rest. Now that we're working in the "real world" we want to re-train it using not just `_train` and `_test` data, but instead **everything we have labels for.**

# %% [markdown]
# ## Filter for planes we want to predict
#
# We have a dataframe of features that includes three types of planes:
#
# * Those that are labeled as surveillance planes
# * Those that are labeled as not surveillance
# * Those that aren't labeled
#
# Which do we want to predictions for? **Filter a new dataframe that's just those.**
#
# * **Tip:** Scroll up to see where you created your `train_df`, it's the opposite!

# %%
df_no_labels=df[df["label"].isna()]

# %% [markdown]
# How many planes do you have in that list? **Confirm it's about 19,200.**

# %%
df_no_labels.shape
# Yes
# Out:
# (19202, 35)

# %% [markdown]
# ## Predicting
#
# Build your `X` - remember you need to drop a few columns - and use that to make a prediction for each plane.
#
# **Assign the prediction into the `predicted` column**.
#
# * **Tip:** Scroll up to see where you created your features for training, it's similar
# * **Tip:** pandas will yell at us about setting values on copies of a slice but it's fine

# %%
df_no_labels.columns
# Out:
# Index(['adshex', 'duration1', 'duration2', 'duration3', 'duration4',
#        'duration5', 'boxes1', 'boxes2', 'boxes3', 'boxes4', 'boxes5', 'speed1',
#        'speed2', 'speed3', 'speed4', 'speed5', 'altitude1', 'altitude2',
#        'altitude3', 'altitude4', 'altitude5', 'steer1', 'steer2', 'steer3',
#        'steer4', 'steer5', 'steer6', 'steer7', 'steer8', 'flights', 'squawk_1',
#        'observations', 'type', 'label', 'type_code'],
#       dtype='object')

# %%
X=df_no_labels.drop(columns=["label","adshex","type"])

# %% [markdown]
# ## How many planes did it predict to be surveillance planes?
#
# It should be roughly around 70-80 planes.

# %%
predictions=forest_model.predict(X)

predictions=pd.DataFrame(predictions, columns=["prediction"])

predictions["prediction"].value_counts()

# Ans: 81 planes
# Out:
# 0.0    19093
# 1.0      109
# Name: prediction, dtype: int64

# %% [markdown]
# ## But.. what about those other ones? The ones that are just below the threshold?
#
# The cutoff for a prediction of `1` is 50%, but since we have a lot of time we're interested in investigating the top 150. To get the probability for each row, you will use `clf.predict_proba` instead of `clf.predict`. Also, to get the predicted probability for the `1` category, you'll need to add `[:,1]` to the end of the
#
# ```python
# clf.predict_proba(***your features***)[:,1]
# ```
#
# **Create a new column called `predicted_prob` that is the chance that the plane is a surveillance plane.**
#
# * **Tip:** You dropped three columns when using `clf.predict`, but if you drop the same three you'll get an error now. There's now an extra column that you'll need to drop! What is it?

# %%
probabilities=forest_model.predict_proba(X)

probabilities=pd.DataFrame(probabilities).add_prefix("proba")

results_df=probabilities.join(predictions).join(df_no_labels)

results_df
# Out:
#          proba0    proba1  prediction  adshex  duration1  duration2  \
# 0      0.996942  0.003058         0.0       A   0.120253   0.075949
# 1      0.961915  0.038085         0.0  A00000   0.211735   0.155612
# 2      0.994882  0.005118         0.0     NaN        NaN        NaN
# 3      0.997511  0.002489         0.0  A00008   0.125000   0.041667
# 4      0.948323  0.051677         0.0  A0001E   0.100000   0.200000
# 5      0.996400  0.003600         0.0  A0002B   0.166667   0.166667
# 6      0.980327  0.019673         0.0  A00049   0.186441   0.118644
# 7      0.865207  0.134793         0.0  A00063   0.214286   0.142857
# 8      0.996362  0.003638         0.0  A00076   0.333333   0.266667
# 9      0.990803  0.009197         0.0  A0007A   0.103448   0.396552
# 10     0.984254  0.015746         0.0  A0008C   0.000000   0.636364
# 11     0.993790  0.006210         0.0  A000C7   0.168539   0.101124
# 12     0.960241  0.039759         0.0  A000DB   0.000000   0.400000
# 13     0.973182  0.026818         0.0  A00116   0.333333   0.266667
# 14     0.998001  0.001999         0.0  A0011D   0.181818   0.151515
# 15     0.787890  0.212110         0.0  A00125   0.089286   0.017857
# 16     0.920006  0.079994         0.0  A00137   0.725490   0.176471
# 17     0.997287  0.002713         0.0  A0013C   0.220779   0.233766
# 18     0.878199  0.121801         0.0  A0019E   0.142857   0.244898
# 19     0.888346  0.111654         0.0  A001A0   0.338870   0.259136
# 20     0.983960  0.016040         0.0  A001AE   0.090909   0.168831
# 21     0.997535  0.002465         0.0  A001BB   0.188235   0.164706
# 22     0.857436  0.142564         0.0  A001CF   0.091837   0.153061
# 23     0.986724  0.013276         0.0  A001F2   0.159574   0.202128
# 24     0.691231  0.308769         0.0  A001FB   0.000000   0.074074
# 25     0.975752  0.024248         0.0  A001FC   0.222222   0.222222
# 26     0.984777  0.015223         0.0  A00203   0.333333   0.074074
# 27     0.952547  0.047453         0.0  A00204   0.229508   0.081967
# 28     0.998121  0.001879         0.0  A00215   0.250000   0.625000
# 29     0.997635  0.002365         0.0     NaN        NaN        NaN
# ...         ...       ...         ...     ...        ...        ...
# 19172  0.686000  0.314000         0.0  AD8154   0.460000   0.120000
# 19173  0.666565  0.333435         0.0  AD815E   0.120930   0.209302
# 19174  0.618822  0.381178         0.0  AD8171   0.000000   0.153846
# 19175  0.814348  0.185652         0.0  AD8184   0.400000   0.381818
# 19176  0.910797  0.089203         0.0  AD8188   0.285714   0.142857
# 19177  0.803742  0.196258         0.0  AD8191   0.000000   0.357143
# 19178  0.837390  0.162610         0.0  AD8194   0.100000   0.100000
# 19179  0.710675  0.289325         0.0  AD81C1   0.076923   0.230769
# 19180  0.854576  0.145424         0.0  AD81D4   0.000000   0.000000
# 19181  0.762330  0.237670         0.0  AD81F4   0.000000   0.000000
# 19182  0.824487  0.175513         0.0  AD8207   0.000000   0.272727
# 19183  0.950637  0.049363         0.0  AD821D   0.294118   0.058824
# 19184  0.814881  0.185119         0.0     NaN        NaN        NaN
# 19185  0.827454  0.172546         0.0  AD822E   0.000000   0.000000
# 19186  0.881572  0.118428         0.0  AD8231   0.093750   0.250000
# 19187  0.840667  0.159333         0.0  AD8247   0.000000   0.000000
# 19188  0.885110  0.114890         0.0  AD825C   0.111111   0.000000
# 19189  0.940180  0.059820         0.0  AD8284   0.000000   0.176471
# 19190  0.929509  0.070491         0.0  AD8295   0.416216   0.200000
# 19191  0.793150  0.206850         0.0  AD829A   0.480000   0.400000
# 19192  0.836706  0.163294         0.0  AD82A3   0.000000   0.062500
# 19193  0.797969  0.202031         0.0  AD82D4   0.054545   0.272727
# 19194  0.747972  0.252028         0.0  AD82FB   0.058824   0.117647
# 19195  0.943573  0.056427         0.0  AD830F   0.238095   0.380952
# 19196  0.974107  0.025893         0.0  AD8328   0.337209   0.360465
# 19197  0.724004  0.275996         0.0  AD8344   0.051282   0.025641
# 19198  0.978263  0.021737         0.0  AD8345   0.000000   0.024390
# 19199  0.805808  0.194192         0.0  AD8352   0.228571   0.342857
# 19200  0.912984  0.087016         0.0  AD83D7   0.181818   0.272727
# 19201  0.940807  0.059193         0.0  AD83E2   0.285714   0.225564
#
#        duration3  duration4  duration5    boxes1    boxes2    boxes3  \
# 0       0.183544   0.335443   0.284810  0.088608  0.044304  0.069620
# 1       0.181122   0.198980   0.252551  0.204082  0.183673  0.168367
# 2            NaN        NaN        NaN       NaN       NaN       NaN
# 3       0.208333   0.166667   0.458333  0.125000  0.083333  0.125000
# 4       0.200000   0.400000   0.100000  0.100000  0.000000  0.100000
# 5       0.000000   0.666667   0.000000  0.333333  0.000000  0.000000
# 6       0.288136   0.169492   0.237288  0.152542  0.067797  0.101695
# 7       0.285714   0.285714   0.071429  0.250000  0.500000  0.142857
# 8       0.222222   0.155556   0.022222  0.466667  0.222222  0.088889
# 9       0.275862   0.103448   0.120690  0.086207  0.396552  0.362069
# 10      0.181818   0.181818   0.000000  0.000000  0.636364  0.363636
# 11      0.179775   0.269663   0.280899  0.146067  0.067416  0.157303
# 12      0.200000   0.200000   0.200000  0.000000  0.400000  0.200000
# 13      0.000000   0.000000   0.400000  0.333333  0.133333  0.133333
# 14      0.393939   0.121212   0.151515  0.181818  0.212121  0.454545
# 15      0.196429   0.267857   0.428571  0.196429  0.107143  0.303571
# 16      0.058824   0.039216   0.000000  0.725490  0.254902  0.019608
# 17      0.155844   0.194805   0.194805  0.181818  0.077922  0.233766
# 18      0.163265   0.183673   0.265306  0.102041  0.102041  0.367347
# 19      0.169435   0.149502   0.083056  0.445183  0.415282  0.116279
# 20      0.129870   0.363636   0.246753  0.090909  0.000000  0.168831
# 21      0.435294   0.188235   0.023529  0.141176  0.047059  0.129412
# 22      0.183673   0.234694   0.336735  0.071429  0.051020  0.112245
# 23      0.382979   0.234043   0.021277  0.138298  0.053191  0.191489
# 24      0.148148   0.222222   0.555556  0.000000  0.000000  0.074074
# 25      0.222222   0.111111   0.222222  0.222222  0.222222  0.111111
# 26      0.333333   0.111111   0.148148  0.222222  0.185185  0.333333
# 27      0.311475   0.049180   0.327869  0.229508  0.131148  0.163934
# 28      0.062500   0.062500   0.000000  0.250000  0.437500  0.250000
# 29           NaN        NaN        NaN       NaN       NaN       NaN
# ...          ...        ...        ...       ...       ...       ...
# 19172   0.180000   0.120000   0.120000  0.400000  0.220000  0.140000
# 19173   0.372093   0.223256   0.074419  0.125581  0.390698  0.404651
# 19174   0.038462   0.269231   0.538462  0.038462  0.038462  0.346154
# 19175   0.127273   0.072727   0.018182  0.418182  0.381818  0.145455
# 19176   0.314286   0.114286   0.142857  0.257143  0.171429  0.228571
# 19177   0.071429   0.571429   0.000000  0.071429  0.428571  0.071429
# 19178   0.200000   0.100000   0.500000  0.100000  0.100000  0.200000
# 19179   0.358974   0.230769   0.102564  0.076923  0.076923  0.256410
# 19180   0.000000   0.333333   0.666667  0.000000  0.000000  0.000000
# 19181   0.333333   0.166667   0.500000  0.000000  0.000000  0.000000
# 19182   0.090909   0.272727   0.363636  0.090909  0.090909  0.181818
# 19183   0.000000   0.176471   0.470588  0.294118  0.117647  0.117647
# 19184        NaN        NaN        NaN       NaN       NaN       NaN
# 19185   0.133333   0.400000   0.466667  0.000000  0.000000  0.000000
# 19186   0.218750   0.281250   0.156250  0.062500  0.375000  0.312500
# 19187   0.000000   0.000000   1.000000  0.000000  0.000000  0.000000
# 19188   0.222222   0.222222   0.444444  0.000000  0.222222  0.333333
# 19189   0.235294   0.235294   0.352941  0.058824  0.117647  0.058824
# 19190   0.145946   0.156757   0.081081  0.497297  0.237838  0.200000
# 19191   0.080000   0.040000   0.000000  0.480000  0.320000  0.120000
# 19192   0.125000   0.250000   0.562500  0.187500  0.000000  0.062500
# 19193   0.363636   0.200000   0.109091  0.036364  0.290909  0.381818
# 19194   0.176471   0.058824   0.588235  0.117647  0.117647  0.117647
# 19195   0.190476   0.000000   0.190476  0.285714  0.380952  0.142857
# 19196   0.209302   0.069767   0.023256  0.383721  0.406977  0.197674
# 19197   0.282051   0.307692   0.333333  0.025641  0.025641  0.128205
# 19198   0.170732   0.365854   0.439024  0.000000  0.000000  0.146341
# 19199   0.142857   0.171429   0.114286  0.257143  0.114286  0.114286
# 19200   0.136364   0.272727   0.136364  0.227273  0.272727  0.500000
# 19201   0.263158   0.127820   0.097744  0.338346  0.225564  0.323308
#
#          boxes4    boxes5    speed1    speed2    speed3    speed4    speed5  \
# 0      0.120253  0.677215  0.021824  0.020550  0.062330  0.100713  0.794582
# 1      0.173469  0.267857  0.107348  0.143410  0.208139  0.177013  0.364090
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      0.166667  0.500000  0.187960  0.278952  0.221048  0.190257  0.121783
# 4      0.400000  0.400000  0.007937  0.026984  0.084127  0.179365  0.701587
# 5      0.666667  0.000000  0.767405  0.191456  0.023734  0.017405  0.000000
# 6      0.338983  0.338983  0.037181  0.037535  0.120751  0.164306  0.640227
# 7      0.107143  0.000000  0.157757  0.830074  0.011951  0.000217  0.000000
# 8      0.200000  0.022222  0.232426  0.204649  0.316893  0.229025  0.017007
# 9      0.000000  0.155172  0.021350  0.079775  0.285263  0.609912  0.003700
# 10     0.000000  0.000000  0.039739  0.138790  0.563464  0.258007  0.000000
# 11     0.235955  0.393258  0.019101  0.069439  0.194787  0.246319  0.470354
# 12     0.000000  0.400000  0.011407  0.054753  0.266920  0.666920  0.000000
# 13     0.000000  0.400000  0.077677  0.024493  0.054584  0.180546  0.662701
# 14     0.060606  0.090909  0.041537  0.567828  0.389857  0.000778  0.000000
# 15     0.125000  0.267857  0.183768  0.161090  0.337474  0.302959  0.014708
# 16     0.000000  0.000000  0.315946  0.292101  0.345753  0.040238  0.005961
# 17     0.207792  0.298701  0.014068  0.017283  0.109727  0.206592  0.652331
# 18     0.204082  0.224490  0.000312  0.015620  0.159169  0.277570  0.547329
# 19     0.003322  0.019934  0.370307  0.379160  0.248631  0.001902  0.000000
# 20     0.298701  0.441558  0.022116  0.091043  0.265389  0.280133  0.341320
# 21     0.529412  0.152941  0.023220  0.073785  0.119358  0.226997  0.556641
# 22     0.142857  0.622449  0.028952  0.082327  0.168359  0.250137  0.470225
# 23     0.265957  0.351064  0.001747  0.001747  0.063483  0.258591  0.674432
# 24     0.000000  0.925926  0.006504  0.005170  0.066711  0.058539  0.863075
# 25     0.222222  0.222222  0.132623  0.261375  0.230397  0.305905  0.069700
# 26     0.111111  0.148148  0.217532  0.287338  0.141234  0.288961  0.064935
# 27     0.114754  0.360656  0.004185  0.016112  0.072819  0.073446  0.833438
# 28     0.062500  0.000000  0.100000  0.595455  0.303409  0.000000  0.001136
# 29          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 19172  0.180000  0.060000  0.135622  0.148498  0.333906  0.357082  0.024893
# 19173  0.074419  0.004651  0.475431  0.447582  0.062516  0.006776  0.007694
# 19174  0.384615  0.192308  0.281796  0.677594  0.039552  0.000987  0.000071
# 19175  0.036364  0.018182  0.222872  0.366472  0.360624  0.035088  0.014945
# 19176  0.228571  0.114286  0.155477  0.400707  0.151943  0.285512  0.006360
# 19177  0.428571  0.000000  0.164199  0.760700  0.075101  0.000000  0.000000
# 19178  0.100000  0.500000  0.031395  0.065891  0.181395  0.255814  0.465504
# 19179  0.487179  0.102564  0.010716  0.058658  0.274676  0.269600  0.386351
# 19180  0.000000  1.000000  0.157219  0.043850  0.101604  0.041711  0.655615
# 19181  0.333333  0.666667  0.441935  0.260215  0.192473  0.067742  0.037634
# 19182  0.000000  0.636364  0.135417  0.043860  0.155702  0.175987  0.489035
# 19183  0.117647  0.352941  0.261874  0.566538  0.171588  0.000000  0.000000
# 19184       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19185  0.200000  0.800000  0.000000  0.024961  0.184087  0.151326  0.639626
# 19186  0.125000  0.125000  0.003380  0.028350  0.120598  0.310326  0.537346
# 19187  0.000000  1.000000  0.423221  0.172285  0.242197  0.138577  0.023720
# 19188  0.222222  0.222222  0.048249  0.074025  0.344349  0.433576  0.099802
# 19189  0.411765  0.352941  0.221298  0.217970  0.226844  0.214642  0.119246
# 19190  0.064865  0.000000  0.432268  0.542173  0.022843  0.000958  0.001757
# 19191  0.080000  0.000000  0.627211  0.314286  0.009524  0.005442  0.043537
# 19192  0.312500  0.437500  0.064156  0.054060  0.256416  0.360538  0.264830
# 19193  0.218182  0.072727  0.022650  0.066131  0.219605  0.495569  0.196046
# 19194  0.294118  0.352941  0.125587  0.444340  0.425005  0.005069  0.000000
# 19195  0.000000  0.190476  0.295732  0.332317  0.326220  0.041667  0.004065
# 19196  0.011628  0.000000  0.447349  0.459915  0.081176  0.005780  0.005780
# 19197  0.333333  0.487179  0.023619  0.079768  0.197415  0.209893  0.489305
# 19198  0.243902  0.609756  0.119832  0.024358  0.114699  0.170322  0.570789
# 19199  0.257143  0.257143  0.010000  0.021250  0.048750  0.116250  0.803750
# 19200  0.000000  0.000000  0.085225  0.431450  0.481936  0.001390  0.000000
# 19201  0.097744  0.015038  0.126248  0.479979  0.392056  0.001718  0.000000
#
#        altitude1  altitude2  altitude3  altitude4  altitude5    steer1  \
# 0       0.042374   0.060971   0.066831   0.106403   0.723421  0.020211
# 1       0.177318   0.114457   0.129648   0.197694   0.380882  0.034976
# 2            NaN        NaN        NaN        NaN        NaN       NaN
# 3       0.014706   0.053309   0.149816   0.279871   0.502298  0.029871
# 4       0.041270   0.085714   0.039683   0.111111   0.722222  0.019048
# 5       0.150316   0.113924   0.178797   0.534810   0.022152  0.001582
# 6       0.032224   0.025850   0.072238   0.172805   0.696884  0.031870
# 7       0.999783   0.000217   0.000000   0.000000   0.000000  0.030204
# 8       0.032313   0.028912   0.454649   0.436508   0.047619  0.043651
# 9       0.253661   0.244258   0.128950   0.373131   0.000000  0.006089
# 10      0.313167   0.526097   0.160735   0.000000   0.000000  0.033215
# 11      0.060684   0.021886   0.019300   0.061281   0.836848  0.019300
# 12      0.277567   0.438023   0.284411   0.000000   0.000000  0.002281
# 13      0.126662   0.082575   0.088873   0.144857   0.557033  0.018894
# 14      0.596453   0.214841   0.076851   0.103609   0.008245  0.007156
# 15      0.155406   0.162614   0.182772   0.299912   0.199297  0.026487
# 16      0.889717   0.105812   0.004471   0.000000   0.000000  0.074516
# 17      0.001608   0.003215   0.024518   0.043408   0.927251  0.024920
# 18      0.068885   0.229616   0.288504   0.121368   0.291628  0.010622
# 19      0.983245   0.015181   0.000787   0.000721   0.000066  0.051969
# 20      0.012901   0.019904   0.056395   0.084777   0.826023  0.042020
# 21      0.045356   0.108073   0.129774   0.195095   0.521701  0.016276
# 22      0.012075   0.032382   0.034989   0.083425   0.837130  0.018112
# 23      0.000582   0.005242   0.013978   0.030868   0.949330  0.039604
# 24      0.162775   0.113242   0.109573   0.131421   0.482989  0.007338
# 25      0.128751   0.324298   0.069700   0.310745   0.166505  0.097773
# 26      0.030844   0.123377   0.366883   0.368506   0.110390  0.035714
# 27      0.010462   0.028458   0.055451   0.110065   0.795564  0.014857
# 28      0.063636   0.223864   0.531818   0.180682   0.000000  0.009091
# 29           NaN        NaN        NaN        NaN        NaN       NaN
# ...          ...        ...        ...        ...        ...       ...
# 19172   0.236052   0.222318   0.302146   0.150215   0.089270  0.054077
# 19173   0.262219   0.489289   0.186675   0.048745   0.013072  0.033881
# 19174   0.166173   0.149535   0.458192   0.105118   0.120981  0.007473
# 19175   0.905783   0.066277   0.020793   0.007147   0.000000  0.083821
# 19176   0.057244   0.076325   0.125795   0.636749   0.103887  0.024028
# 19177   0.076178   0.371198   0.452221   0.100404   0.000000  0.011844
# 19178   0.196124   0.078682   0.084884   0.139535   0.500775  0.009690
# 19179   0.005640   0.007332   0.023125   0.209814   0.754089  0.023125
# 19180   0.204278   0.100535   0.135829   0.087701   0.471658  0.018182
# 19181   0.007527   0.023656   0.137634   0.830108   0.001075  0.006452
# 19182   0.161184   0.098684   0.162829   0.160088   0.417215  0.020833
# 19183   0.070817   0.074240   0.177578   0.529097   0.148267  0.010484
# 19184        NaN        NaN        NaN        NaN        NaN       NaN
# 19185   0.023401   0.006240   0.010920   0.017161   0.942278  0.018721
# 19186   0.275761   0.097154   0.192345   0.432886   0.001854  0.035874
# 19187   0.000000   0.002497   0.004994   0.887640   0.104869  0.014981
# 19188   0.040978   0.007270   0.011897   0.188367   0.751487  0.017184
# 19189   0.042707   0.031059   0.058791   0.090405   0.777038  0.017194
# 19190   0.556550   0.313099   0.123482   0.006869   0.000000  0.061342
# 19191   0.580952   0.232653   0.121088   0.065306   0.000000  0.031293
# 19192   0.129785   0.146403   0.139462   0.307320   0.277030  0.011780
# 19193   0.290281   0.295508   0.162639   0.242330   0.009242  0.016438
# 19194   0.100619   0.082410   0.072836   0.284400   0.459733  0.007133
# 19195   0.310976   0.384146   0.286585   0.018293   0.000000  0.028455
# 19196   0.334255   0.467957   0.186479   0.011309   0.000000  0.037698
# 19197   0.004011   0.007130   0.019162   0.068182   0.901515  0.026292
# 19198   0.268689   0.145964   0.123752   0.163136   0.298460  0.020345
# 19199   0.011250   0.065000   0.057500   0.072500   0.793750  0.030000
# 19200   0.969662   0.030338   0.000000   0.000000   0.000000  0.011348
# 19201   0.003221   0.000000   0.167364   0.715083   0.114332  0.029093
#
#          steer2    steer3    steer4    steer5    steer6    steer7    steer8  \
# 0      0.048913  0.270550  0.344090  0.097317  0.186651  0.011379  0.009426
# 1      0.048127  0.240732  0.356314  0.116116  0.159325  0.012828  0.013628
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      0.044118  0.202665  0.380515  0.094669  0.182904  0.014706  0.020221
# 4      0.049206  0.249206  0.326984  0.112698  0.206349  0.012698  0.011111
# 5      0.009494  0.281646  0.416139  0.112342  0.169304  0.001582  0.001582
# 6      0.042139  0.188385  0.452904  0.089589  0.153683  0.007790  0.014518
# 7      0.047805  0.344415  0.191439  0.130378  0.212516  0.014993  0.008040
# 8      0.031179  0.129252  0.586735  0.049887  0.098639  0.009070  0.018707
# 9      0.011022  0.224757  0.496994  0.139664  0.106367  0.003931  0.003006
# 10     0.026690  0.247331  0.399763  0.167260  0.097865  0.006524  0.007711
# 11     0.026462  0.237167  0.417429  0.096498  0.158973  0.007959  0.013530
# 12     0.008365  0.266160  0.386312  0.186312  0.139163  0.003802  0.003042
# 13     0.016095  0.241428  0.454864  0.135059  0.102169  0.009097  0.005598
# 14     0.008401  0.273958  0.417859  0.186839  0.091630  0.003889  0.004823
# 15     0.034281  0.268796  0.305245  0.133490  0.182948  0.018107  0.013243
# 16     0.043219  0.265276  0.183308  0.096870  0.184799  0.034277  0.055142
# 17     0.013666  0.107717  0.688103  0.063907  0.049437  0.002412  0.017283
# 18     0.028116  0.178694  0.547173  0.112777  0.095595  0.008747  0.005936
# 19     0.067740  0.223614  0.306797  0.107479  0.158104  0.028460  0.023640
# 20     0.061555  0.217471  0.308883  0.070402  0.218577  0.020641  0.025065
# 21     0.028212  0.222873  0.500868  0.093967  0.111545  0.004774  0.006293
# 22     0.026070  0.198134  0.499451  0.100439  0.125274  0.009056  0.011389
# 23     0.020967  0.140944  0.557368  0.066395  0.096098  0.008736  0.026791
# 24     0.022515  0.183289  0.532188  0.118746  0.118746  0.006004  0.005003
# 25     0.055179  0.268151  0.292352  0.090029  0.141336  0.011617  0.013553
# 26     0.032468  0.139610  0.530844  0.058442  0.125000  0.014610  0.019481
# 27     0.027830  0.197531  0.500314  0.096464  0.133082  0.005440  0.008579
# 28     0.015909  0.376136  0.237500  0.129545  0.205682  0.004545  0.003409
# 29          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 19172  0.045494  0.273820  0.225751  0.104721  0.199142  0.024034  0.028326
# 19173  0.043281  0.273061  0.231180  0.113360  0.229562  0.022427  0.021422
# 19174  0.027496  0.340595  0.232727  0.145093  0.228356  0.008954  0.003173
# 19175  0.066927  0.251462  0.176738  0.067576  0.215724  0.039636  0.033788
# 19176  0.039576  0.175972  0.496113  0.092580  0.126502  0.010601  0.011307
# 19177  0.022342  0.351548  0.246299  0.135397  0.216420  0.005384  0.003499
# 19178  0.028682  0.205039  0.519767  0.106202  0.118217  0.004651  0.002326
# 19179  0.020869  0.183869  0.543711  0.068246  0.116751  0.006768  0.014100
# 19180  0.021390  0.177540  0.567914  0.100535  0.082353  0.010695  0.009626
# 19181  0.015054  0.290323  0.401075  0.090323  0.177419  0.006452  0.004301
# 19182  0.028509  0.249452  0.397478  0.138158  0.126096  0.010965  0.013706
# 19183  0.022893  0.331408  0.335473  0.187848  0.103338  0.002353  0.001926
# 19184       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19185  0.023401  0.191888  0.521061  0.067083  0.121685  0.003120  0.012480
# 19186  0.032058  0.260386  0.343147  0.152110  0.137717  0.008723  0.011013
# 19187  0.033708  0.263421  0.340824  0.111111  0.207241  0.011236  0.001248
# 19188  0.032386  0.192994  0.454065  0.129544  0.139458  0.015863  0.009914
# 19189  0.056018  0.197449  0.451470  0.086522  0.165280  0.013311  0.006101
# 19190  0.044249  0.228754  0.246645  0.108307  0.191693  0.028914  0.044569
# 19191  0.029932  0.259864  0.346939  0.093878  0.187755  0.009524  0.013605
# 19192  0.013462  0.266512  0.409550  0.158814  0.117796  0.007152  0.005679
# 19193  0.032195  0.185592  0.510567  0.119233  0.109992  0.009923  0.005909
# 19194  0.011076  0.256054  0.455416  0.158814  0.103623  0.001690  0.002816
# 19195  0.052846  0.261179  0.277439  0.128049  0.205285  0.016260  0.011179
# 19196  0.037698  0.256346  0.296557  0.120885  0.184971  0.019352  0.018849
# 19197  0.039661  0.208111  0.424242  0.069073  0.174688  0.011141  0.020053
# 19198  0.026598  0.144750  0.580868  0.086608  0.105926  0.012972  0.009333
# 19199  0.035000  0.158750  0.482500  0.062500  0.132500  0.013750  0.028750
# 19200  0.012969  0.340204  0.320750  0.160491  0.134553  0.004400  0.002316
# 19201  0.033816  0.328180  0.200966  0.144820  0.211487  0.012990  0.015781
#
#        flights  squawk_1  observations     type  label  type_code
# 0        158.0       0.0       11776.0     GRND    NaN      248.0
# 1        392.0       0.0       52465.0     TBM7    NaN      431.0
# 2          NaN       NaN           NaN      NaN    NaN        NaN
# 3         24.0       0.0        2176.0     PA46    NaN      350.0
# 4         10.0    1135.0         630.0     C56X    NaN      126.0
# 5          6.0    2356.0         632.0     C82S    NaN      133.0
# 6         59.0       0.0        2824.0     PC12    NaN      356.0
# 7         28.0       0.0        4602.0      R66    NaN      369.0
# 8         45.0       0.0        1764.0     DA42    NaN      164.0
# 9         58.0    1200.0       12974.0     BE36    NaN       54.0
# 10        11.0    1200.0        1686.0  unknown    NaN      454.0
# 11        89.0       0.0        5026.0     BE20    NaN       48.0
# 12         5.0    1200.0        1315.0  unknown    NaN      454.0
# 13        15.0    3354.0        1429.0     BE9T    NaN       70.0
# 14        33.0       0.0        6428.0     B407    NaN       35.0
# 15        56.0    1200.0       17065.0     SR22    NaN      406.0
# 16        51.0       0.0         671.0     A139    NaN        3.0
# 17        77.0       0.0        2488.0     BE20    NaN       48.0
# 18        49.0       0.0        6402.0     BE9L    NaN       69.0
# 19       301.0       0.0       30499.0     B429    NaN       38.0
# 20        77.0       0.0        2713.0     PC12    NaN      356.0
# 21        85.0       0.0        4608.0     B350    NaN       33.0
# 22        98.0       0.0        7288.0     TBM8    NaN      432.0
# 23        94.0       0.0        1717.0     EPIC    NaN      205.0
# 24        27.0    2320.0        5996.0     GLF4    NaN      240.0
# 25         9.0    7754.0        1033.0     BE35    NaN       53.0
# 26        27.0       0.0         616.0     BE36    NaN       54.0
# 27        61.0       0.0        4779.0     B350    NaN       33.0
# 28        16.0       0.0         880.0     ALIG    NaN       15.0
# 29         NaN       NaN           NaN      NaN    NaN        NaN
# ...        ...       ...           ...      ...    ...        ...
# 19172     50.0       0.0        1165.0     B36T    NaN       34.0
# 19173    215.0       0.0       22874.0     C172    NaN       88.0
# 19174     26.0    1200.0       14184.0     GLST    NaN      246.0
# 19175     55.0       0.0        1539.0     DA40    NaN      163.0
# 19176     35.0       0.0        1415.0     SR22    NaN      406.0
# 19177     14.0    1200.0        3715.0     RV12    NaN      375.0
# 19178     10.0    3055.0        2580.0     PA46    NaN      350.0
# 19179     39.0       0.0        1773.0     BE9L    NaN       69.0
# 19180      3.0    2411.0         935.0     GLF4    NaN      240.0
# 19181      6.0    2043.0         930.0  unknown    NaN      454.0
# 19182     11.0       0.0        1824.0     BE9T    NaN       70.0
# 19183     17.0    1200.0        4674.0  unknown    NaN      454.0
# 19184      NaN       NaN           NaN      NaN    NaN        NaN
# 19185     15.0       0.0         641.0     BE9L    NaN       69.0
# 19186     32.0    1200.0        9171.0     GLAS    NaN      236.0
# 19187      4.0    1711.0         801.0     PA32    NaN      347.0
# 19188      9.0    1200.0        1513.0     SR22    NaN      406.0
# 19189     17.0    1200.0        1803.0  unknown    NaN      454.0
# 19190    185.0       0.0        6260.0     C172    NaN       88.0
# 19191     25.0    1200.0         735.0      B06    NaN       27.0
# 19192     16.0    6516.0        4754.0     C340    NaN      110.0
# 19193     55.0    1200.0       13201.0     BE58    NaN       60.0
# 19194     17.0    1200.0        5327.0     LA25    NaN      278.0
# 19195     21.0       0.0         984.0     P28R    NaN      325.0
# 19196     86.0       0.0        3979.0     C172    NaN       88.0
# 19197     39.0       0.0        2244.0     BE10    NaN       45.0
# 19198     41.0       0.0       10715.0     BE20    NaN       48.0
# 19199     35.0       0.0         800.0     AC90    NaN       10.0
# 19200     22.0    4511.0        4318.0     B407    NaN       35.0
# 19201    133.0    1200.0        9315.0     B407    NaN       35.0
#
# [19202 rows x 38 columns]

# %% [markdown]
# ### Get the top 200 predictions
#
# Take a look at what the probabilities look like, showing the top 200 planes that are **most likely to be surveillance planes.**
#
# Then save them to a file for later research.

# %%
top_200=results_df.sort_values(by="proba1", ascending=False).head(200)

# %%
top_200
# Out:
#          proba0    proba1  prediction  adshex  duration1  duration2  \
# 11678  0.058043  0.941957         1.0  A7941A   0.303030   0.212121
# 7869   0.082011  0.917989         1.0  A4E1B2   0.076923   0.153846
# 3019   0.113492  0.886508         1.0  A1A952   0.071429   0.357143
# 9612   0.137920  0.862080         1.0  A60EC5   0.235294   0.058824
# 7139   0.139302  0.860698         1.0  A46285   0.142857   0.214286
# 2123   0.150514  0.849486         1.0  A12389   0.083333   0.125000
# 17621  0.156262  0.843738         1.0  AC5302   0.018868   0.132075
# 2171   0.168020  0.831980         1.0  A12CDF   0.083333   0.083333
# 16278  0.169505  0.830495         1.0     NaN        NaN        NaN
# 13836  0.172537  0.827463         1.0  A954AD   0.000000   0.038462
# 4073   0.197968  0.802032         1.0  A231DB   0.000000   0.127660
# 83     0.209973  0.790027         1.0  A005CB   0.000000   0.142857
# 13419  0.212318  0.787682         1.0  A8F262   0.149425   0.080460
# 2231   0.214157  0.785843         1.0  A1387B   0.105263   0.157895
# 17803  0.231750  0.768250         1.0  AC7331   0.000000   0.125000
# 9742   0.233576  0.766424         1.0  A63301   0.230769   0.076923
# 11853  0.242410  0.757590         1.0  A7C4F6   0.200000   0.066667
# 7831   0.243117  0.756883         1.0  A4DC0E   0.142857   0.357143
# 119    0.245716  0.754284         1.0  A00824   0.000000   0.000000
# 10805  0.245884  0.754116         1.0  A6D91F   0.078431   0.058824
# 17780  0.253229  0.746771         1.0  AC70A7   0.000000   0.000000
# 19092  0.253972  0.746028         1.0  AD6BCC   0.000000   0.272727
# 993    0.262740  0.737260         1.0  A06474   0.000000   0.117647
# 4341   0.265363  0.734637         1.0  A25B73   0.104167   0.291667
# 11781  0.273209  0.726791         1.0  A7B19C   0.250000   0.194444
# 7475   0.282425  0.717575         1.0  A4ADD2   0.000000   0.538462
# 8607   0.283860  0.716140         1.0  A54981   0.000000   0.090909
# 9146   0.290962  0.709038         1.0  A59E9A   0.333333   0.153846
# 7113   0.292766  0.707234         1.0  A45CF5   0.125000   0.375000
# 15379  0.293865  0.706135         1.0  AA7607   0.000000   0.142857
# ...         ...       ...         ...     ...        ...        ...
# 3107   0.567181  0.432819         0.0  A1B3D7   0.137931   0.068966
# 8256   0.567939  0.432061         0.0  A50B47   0.000000   0.086957
# 12750  0.568128  0.431872         0.0  A85449   0.043478   0.217391
# 2032   0.568228  0.431772         0.0  A1135D   0.352941   0.441176
# 3941   0.569539  0.430461         0.0     NaN        NaN        NaN
# 9785   0.571082  0.428918         0.0  A6378D   0.285714   0.357143
# 3284   0.571918  0.428082         0.0  A1C49B   0.055556   0.333333
# 16842  0.573040  0.426960         0.0  AB94F3   0.411765   0.058824
# 19120  0.573362  0.426638         0.0  AD7402   0.371429   0.400000
# 5370   0.573859  0.426141         0.0  A336ED   0.035714   0.285714
# 6912   0.574175  0.425825         0.0  A42F0A   0.000000   0.125000
# 7125   0.576017  0.423983         0.0  A45FB3   0.346535   0.148515
# 1924   0.576245  0.423755         0.0  A0F95A   0.200000   0.100000
# 9413   0.576909  0.423091         0.0  A5DDCB   0.095238   0.071429
# 9441   0.578280  0.421720         0.0  A5E204   0.214286   0.071429
# 18123  0.578330  0.421670         0.0  ACA99D   0.135135   0.351351
# 7465   0.579209  0.420791         0.0  A4ACFA   0.043478   0.086957
# 15243  0.579615  0.420385         0.0  AA5BD7   0.027027   0.027027
# 17223  0.579976  0.420024         0.0  ABF421   0.117647   0.000000
# 10498  0.580543  0.419457         0.0  A6A2DD   0.117647   0.323529
# 13896  0.581850  0.418150         0.0  A95640   0.102564   0.000000
# 17336  0.582188  0.417812         0.0  AC126F   0.382353   0.147059
# 5779   0.582413  0.417587         0.0  A3725E   0.200000   0.100000
# 1854   0.583667  0.416333         0.0  A0ED30   0.100000   0.300000
# 4156   0.587203  0.412797         0.0  A240B7   0.045455   0.181818
# 12427  0.587379  0.412621         0.0  A815E6   0.000000   0.000000
# 18743  0.588231  0.411769         0.0  AD20D1   0.184211   0.210526
# 14521  0.588935  0.411065         0.0  A9BE40   0.165049   0.067961
# 10292  0.589207  0.410793         0.0  A68745   0.181818   0.090909
# 896    0.589362  0.410638         0.0  A05C34   0.157895   0.368421
#
#        duration3  duration4  duration5    boxes1    boxes2    boxes3  \
# 11678   0.121212   0.181818   0.181818  0.272727  0.151515  0.212121
# 7869    0.076923   0.153846   0.538462  0.076923  0.153846  0.230769
# 3019    0.214286   0.142857   0.214286  0.142857  0.285714  0.285714
# 9612    0.000000   0.235294   0.470588  0.117647  0.117647  0.058824
# 7139    0.071429   0.142857   0.428571  0.142857  0.142857  0.357143
# 2123    0.250000   0.208333   0.333333  0.125000  0.083333  0.750000
# 17621   0.150943   0.301887   0.396226  0.018868  0.169811  0.528302
# 2171    0.333333   0.250000   0.250000  0.083333  0.250000  0.333333
# 16278        NaN        NaN        NaN       NaN       NaN       NaN
# 13836   0.038462   0.115385   0.807692  0.000000  0.038462  0.076923
# 4073    0.127660   0.531915   0.212766  0.085106  0.659574  0.191489
# 83      0.142857   0.142857   0.571429  0.000000  0.142857  0.142857
# 13419   0.172414   0.482759   0.114943  0.160920  0.471264  0.298851
# 2231    0.157895   0.421053   0.157895  0.105263  0.052632  0.315789
# 17803   0.187500   0.187500   0.500000  0.000000  0.062500  0.062500
# 9742    0.076923   0.000000   0.615385  0.153846  0.076923  0.000000
# 11853   0.320000   0.360000   0.053333  0.173333  0.040000  0.053333
# 7831    0.071429   0.071429   0.357143  0.142857  0.357143  0.214286
# 119     0.222222   0.111111   0.666667  0.000000  0.000000  0.000000
# 10805   0.294118   0.264706   0.303922  0.058824  0.029412  0.049020
# 17780   0.444444   0.111111   0.444444  0.000000  0.000000  0.111111
# 19092   0.363636   0.090909   0.272727  0.090909  0.272727  0.454545
# 993     0.058824   0.058824   0.764706  0.000000  0.000000  0.235294
# 4341    0.250000   0.104167   0.250000  0.062500  0.083333  0.208333
# 11781   0.333333   0.083333   0.138889  0.194444  0.277778  0.361111
# 7475    0.307692   0.153846   0.000000  0.153846  0.461538  0.384615
# 8607    0.636364   0.090909   0.181818  0.090909  0.000000  0.727273
# 9146    0.128205   0.153846   0.230769  0.282051  0.153846  0.076923
# 7113    0.000000   0.500000   0.000000  0.500000  0.500000  0.000000
# 15379   0.000000   0.000000   0.857143  0.000000  0.000000  0.214286
# ...          ...        ...        ...       ...       ...       ...
# 3107    0.137931   0.293103   0.362069  0.103448  0.051724  0.068966
# 8256    0.565217   0.043478   0.304348  0.000000  0.130435  0.478261
# 12750   0.260870   0.347826   0.130435  0.043478  0.347826  0.130435
# 2032    0.147059   0.058824   0.000000  0.382353  0.352941  0.205882
# 3941         NaN        NaN        NaN       NaN       NaN       NaN
# 9785    0.000000   0.000000   0.357143  0.285714  0.142857  0.214286
# 3284    0.333333   0.111111   0.166667  0.055556  0.222222  0.555556
# 16842   0.411765   0.000000   0.117647  0.470588  0.058824  0.470588
# 19120   0.171429   0.028571   0.028571  0.171429  0.457143  0.314286
# 5370    0.285714   0.196429   0.196429  0.035714  0.196429  0.267857
# 6912    0.166667   0.083333   0.625000  0.000000  0.333333  0.083333
# 7125    0.128713   0.217822   0.158416  0.257426  0.099010  0.108911
# 1924    0.200000   0.200000   0.300000  0.400000  0.000000  0.400000
# 9413    0.428571   0.261905   0.142857  0.119048  0.071429  0.214286
# 9441    0.535714   0.142857   0.035714  0.142857  0.464286  0.250000
# 18123   0.189189   0.243243   0.081081  0.162162  0.405405  0.162162
# 7465    0.065217   0.326087   0.478261  0.000000  0.086957  0.086957
# 15243   0.189189   0.648649   0.108108  0.054054  0.081081  0.432432
# 17223   0.176471   0.117647   0.588235  0.117647  0.000000  0.117647
# 10498   0.176471   0.264706   0.117647  0.029412  0.588235  0.205882
# 13896   0.205128   0.256410   0.435897  0.102564  0.000000  0.076923
# 17336   0.220588   0.132353   0.117647  0.455882  0.338235  0.117647
# 5779    0.100000   0.200000   0.400000  0.200000  0.000000  0.300000
# 1854    0.500000   0.100000   0.000000  0.300000  0.300000  0.000000
# 4156    0.363636   0.227273   0.181818  0.272727  0.363636  0.181818
# 12427   1.000000   0.000000   0.000000  0.000000  1.000000  0.000000
# 18743   0.210526   0.236842   0.157895  0.394737  0.263158  0.105263
# 14521   0.067961   0.126214   0.572816  0.126214  0.067961  0.067961
# 10292   0.363636   0.181818   0.181818  0.181818  0.181818  0.272727
# 896     0.315789   0.052632   0.105263  0.105263  0.157895  0.210526
#
#          boxes4    boxes5    speed1    speed2    speed3    speed4    speed5  \
# 11678  0.212121  0.151515  0.046512  0.139535  0.303779  0.395349  0.114826
# 7869   0.307692  0.230769  0.763190  0.106748  0.112883  0.008589  0.008589
# 3019   0.142857  0.142857  0.052734  0.304688  0.572266  0.039062  0.031250
# 9612   0.000000  0.705882  0.040573  0.050119  0.199682  0.247414  0.462212
# 7139   0.000000  0.357143  0.034988  0.089115  0.229665  0.426734  0.219498
# 2123   0.041667  0.000000  0.296853  0.680388  0.022759  0.000000  0.000000
# 17621  0.169811  0.113208  0.120769  0.203584  0.448595  0.226932  0.000120
# 2171   0.333333  0.000000  0.129649  0.342886  0.527465  0.000000  0.000000
# 16278       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13836  0.038462  0.846154  0.032160  0.039294  0.123845  0.179043  0.625658
# 4073   0.063830  0.000000  0.624947  0.371115  0.003938  0.000000  0.000000
# 83     0.000000  0.714286  0.050877  0.087719  0.147368  0.178947  0.535088
# 13419  0.068966  0.000000  0.368353  0.527886  0.088197  0.015564  0.000000
# 2231   0.052632  0.473684  0.050768  0.110888  0.185705  0.262525  0.390114
# 17803  0.312500  0.562500  0.017495  0.189687  0.226519  0.418969  0.147330
# 9742   0.153846  0.615385  0.002047  0.001024  0.033777  0.100307  0.862845
# 11853  0.320000  0.413333  0.007464  0.033891  0.163405  0.211620  0.583619
# 7831   0.071429  0.214286  0.241740  0.727102  0.031159  0.000000  0.000000
# 119    0.333333  0.666667  0.089505  0.066931  0.045149  0.055842  0.742574
# 10805  0.362745  0.500000  0.015335  0.073645  0.164586  0.197753  0.548680
# 17780  0.444444  0.444444  0.012174  0.043478  0.153043  0.226087  0.565217
# 19092  0.090909  0.090909  0.056479  0.171949  0.582366  0.189206  0.000000
# 993    0.117647  0.647059  0.028357  0.205563  0.638744  0.127227  0.000109
# 4341   0.166667  0.479167  0.018729  0.019064  0.045151  0.097324  0.819732
# 11781  0.111111  0.055556  0.223404  0.495090  0.126841  0.086743  0.067921
# 7475   0.000000  0.000000  0.532099  0.391975  0.070370  0.001852  0.003704
# 8607   0.000000  0.181818  0.304636  0.244402  0.321980  0.124882  0.004100
# 9146   0.153846  0.333333  0.128863  0.079883  0.160350  0.194752  0.436152
# 7113   0.000000  0.000000  1.000000  0.000000  0.000000  0.000000  0.000000
# 15379  0.071429  0.714286  0.010561  0.053090  0.130013  0.594976  0.211360
# ...         ...       ...       ...       ...       ...       ...       ...
# 3107   0.120690  0.655172  0.008092  0.015346  0.060547  0.134766  0.781250
# 8256   0.130435  0.260870  0.025375  0.017816  0.354029  0.594547  0.008233
# 12750  0.347826  0.130435  0.063712  0.055006  0.156839  0.492679  0.231764
# 2032   0.058824  0.000000  0.800000  0.093421  0.059211  0.025000  0.022368
# 3941        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9785   0.071429  0.285714  0.011218  0.014423  0.100962  0.528846  0.344551
# 3284   0.111111  0.055556  0.169624  0.407900  0.393959  0.028517  0.000000
# 16842  0.000000  0.000000  0.757037  0.161481  0.032593  0.018519  0.030370
# 19120  0.057143  0.000000  0.183805  0.118252  0.393316  0.227506  0.077121
# 5370   0.339286  0.160714  0.047495  0.056826  0.188789  0.501193  0.205697
# 6912   0.083333  0.500000  0.022217  0.073945  0.256059  0.559807  0.087971
# 7125   0.178218  0.356436  0.060705  0.065628  0.095980  0.151217  0.626470
# 1924   0.200000  0.000000  0.150860  0.121747  0.490516  0.236877  0.000000
# 9413   0.404762  0.190476  0.258415  0.248615  0.387729  0.059012  0.046229
# 9441   0.107143  0.035714  0.067109  0.169125  0.738201  0.024828  0.000737
# 18123  0.216216  0.054054  0.250996  0.313856  0.347942  0.050907  0.036299
# 7465   0.369565  0.456522  0.011451  0.055735  0.156752  0.587095  0.188967
# 15243  0.324324  0.108108  0.182629  0.091591  0.463008  0.261745  0.001026
# 17223  0.058824  0.705882  0.002845  0.018492  0.196302  0.423898  0.358464
# 10498  0.147059  0.029412  0.276939  0.608986  0.114075  0.000000  0.000000
# 13896  0.282051  0.538462  0.116486  0.051400  0.164704  0.225334  0.442075
# 17336  0.029412  0.058824  0.732278  0.203997  0.035822  0.004148  0.023756
# 5779   0.100000  0.400000  0.000000  0.116239  0.865590  0.018171  0.000000
# 1854   0.400000  0.000000  0.034014  0.049563  0.487852  0.428571  0.000000
# 4156   0.181818  0.000000  0.506773  0.458333  0.032635  0.001437  0.000821
# 12427  0.000000  0.000000  0.166881  0.833119  0.000000  0.000000  0.000000
# 18743  0.236842  0.000000  0.477162  0.416910  0.069971  0.007775  0.028183
# 14521  0.077670  0.660194  0.011798  0.029613  0.077867  0.178150  0.702572
# 10292  0.272727  0.090909  0.696352  0.155579  0.134120  0.009657  0.004292
# 896    0.421053  0.105263  0.007722  0.063707  0.200772  0.281853  0.445946
#
#        altitude1  altitude2  altitude3  altitude4  altitude5    steer1  \
# 11678   0.084302   0.072674   0.122093   0.319767   0.401163  0.026163
# 7869    0.002454   0.089571   0.274847   0.633129   0.000000  0.020859
# 3019    0.019531   0.079102   0.121094   0.559570   0.220703  0.016602
# 9612    0.018298   0.027844   0.024662   0.107399   0.821798  0.021480
# 7139    0.056519   0.055622   0.046950   0.365132   0.475778  0.026316
# 2123    0.337033   0.516016   0.101292   0.045659   0.000000  0.007727
# 17621   0.349258   0.439017   0.207256   0.004470   0.000000  0.006825
# 2171    0.604572   0.097578   0.258274   0.039577   0.000000  0.017059
# 16278        NaN        NaN        NaN        NaN        NaN       NaN
# 13836   0.144778   0.123845   0.127587   0.116595   0.487194  0.006081
# 4073    0.418065   0.410735   0.161325   0.009875   0.000000  0.048888
# 83      0.005263   0.050877   0.163158   0.101754   0.678947  0.017544
# 13419   0.324254   0.367056   0.237354   0.071336   0.000000  0.114137
# 2231    0.046092   0.068804   0.179025   0.272545   0.433534  0.038076
# 17803   0.011971   0.009208   0.017495   0.253223   0.708103  0.016575
# 9742    0.000000   0.003071   0.007165   0.036847   0.952917  0.014330
# 11853   0.014727   0.024612   0.064757   0.184184   0.711721  0.011902
# 7831    0.134253   0.294437   0.214555   0.258887   0.097867  0.005855
# 119     0.273267   0.111287   0.101386   0.116040   0.398020  0.013861
# 10805   0.013552   0.025678   0.034415   0.084165   0.842190  0.024429
# 17780   0.036522   0.041739   0.099130   0.210435   0.612174  0.026087
# 19092   0.194227   0.447129   0.115155   0.243489   0.000000  0.023847
# 993     0.059974   0.099413   0.155802   0.589092   0.095719  0.004998
# 4341    0.010033   0.021070   0.066555   0.074916   0.827425  0.008696
# 11781   0.029460   0.105565   0.319967   0.336334   0.208674  0.029460
# 7475    0.246296   0.530864   0.222840   0.000000   0.000000  0.033333
# 8607    0.253548   0.219489   0.221381   0.148218   0.157364  0.025229
# 9146    0.013411   0.046647   0.126531   0.090962   0.722449  0.015743
# 7113    0.975363   0.024637   0.000000   0.000000   0.000000  0.029059
# 15379   0.069645   0.149707   0.135721   0.533895   0.111032  0.004995
# ...          ...        ...        ...        ...        ...       ...
# 3107    0.015904   0.032087   0.042411   0.068080   0.841518  0.019810
# 8256    0.050614   0.100823   0.151977   0.293562   0.403023  0.010528
# 12750   0.285450   0.176230   0.203799   0.238755   0.095766  0.010157
# 2032    0.113158   0.438158   0.176316   0.272368   0.000000  0.060526
# 3941         NaN        NaN        NaN        NaN        NaN       NaN
# 9785    0.046474   0.326923   0.219551   0.407051   0.000000  0.016026
# 3284    0.280524   0.406633   0.257076   0.055767   0.000000  0.010773
# 16842   0.225185   0.491852   0.282963   0.000000   0.000000  0.039259
# 19120   0.006427   0.340617   0.392031   0.217224   0.043702  0.048843
# 5370    0.235373   0.179388   0.187386   0.126491   0.271362  0.007296
# 6912    0.122083   0.131620   0.096611   0.332024   0.317662  0.009650
# 7125    0.015587   0.020782   0.050861   0.114028   0.798742  0.028165
# 1924    0.295104   0.176445   0.179091   0.230701   0.118659  0.028672
# 9413    0.085428   0.187473   0.392416   0.334683   0.000000  0.026843
# 9441    0.196165   0.554572   0.155113   0.093658   0.000492  0.008850
# 18123   0.083223   0.169544   0.187694   0.439132   0.120407  0.022134
# 7465    0.101920   0.115889   0.153853   0.341870   0.286468  0.004229
# 15243   0.522385   0.152783   0.182945   0.141887   0.000000  0.013265
# 17223   0.007112   0.011380   0.021337   0.960171   0.000000  0.024182
# 10498   0.162513   0.434363   0.302562   0.100562   0.000000  0.009477
# 13896   0.149905   0.067314   0.136537   0.185391   0.460853  0.019733
# 17336   0.503394   0.209653   0.176094   0.107089   0.003771  0.070890
# 5779    0.083646   0.033170   0.050187   0.804442   0.028555  0.002019
# 1854    0.235180   0.344995   0.362488   0.057337   0.000000  0.086492
# 4156    0.177135   0.328612   0.099138   0.237479   0.157635  0.029146
# 12427   0.003851   0.120026   0.876123   0.000000   0.000000  0.008986
# 18743   0.068999   0.354713   0.418853   0.157434   0.000000  0.058309
# 14521   0.007433   0.012624   0.019703   0.043181   0.917060  0.021000
# 10292   0.012876   0.118026   0.334764   0.534335   0.000000  0.008584
# 896     0.038610   0.121622   0.210425   0.252896   0.376448  0.034749
#
#          steer2    steer3    steer4    steer5    steer6    steer7    steer8  \
# 11678  0.023256  0.142442  0.505814  0.090116  0.122093  0.013081  0.027616
# 7869   0.023313  0.213497  0.476074  0.110429  0.123926  0.004908  0.008589
# 3019   0.030273  0.207031  0.487305  0.085938  0.145508  0.011719  0.007812
# 9612   0.054097  0.271281  0.307080  0.105012  0.210024  0.009547  0.008751
# 7139   0.054426  0.294856  0.293660  0.162081  0.138756  0.010167  0.004785
# 2123   0.016297  0.302051  0.346446  0.153976  0.147232  0.006041  0.005198
# 17621  0.028776  0.277219  0.370330  0.136814  0.158325  0.004989  0.002794
# 2171   0.019106  0.284886  0.297168  0.141931  0.196520  0.016377  0.016035
# 16278       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13836  0.019179  0.292480  0.346392  0.169103  0.150743  0.005263  0.005029
# 4073   0.048404  0.294057  0.202581  0.106258  0.222269  0.029200  0.019567
# 83     0.029825  0.187719  0.521053  0.073684  0.114035  0.007018  0.017544
# 13419  0.018158  0.046693  0.501946  0.007782  0.062257  0.012970  0.090791
# 2231   0.064128  0.256513  0.253841  0.086840  0.227121  0.027388  0.022712
# 17803  0.023941  0.134438  0.643646  0.062615  0.074586  0.006446  0.013812
# 9742   0.031730  0.249744  0.392016  0.122825  0.160696  0.010235  0.007165
# 11853  0.029252  0.242889  0.392173  0.099657  0.196288  0.007868  0.009078
# 7831   0.012965  0.253660  0.454831  0.155793  0.099749  0.008992  0.002719
# 119    0.037624  0.184158  0.523168  0.098614  0.118812  0.009901  0.006733
# 10805  0.033345  0.203281  0.427960  0.096469  0.157454  0.011056  0.016762
# 17780  0.062609  0.246957  0.368696  0.083478  0.170435  0.019130  0.006957
# 19092  0.030750  0.213994  0.413869  0.128020  0.153122  0.015375  0.010041
# 993    0.013472  0.110821  0.740874  0.081160  0.038787  0.003151  0.002282
# 4341   0.019398  0.202676  0.546488  0.090301  0.108696  0.004013  0.007358
# 11781  0.025368  0.166121  0.527823  0.078560  0.106383  0.008183  0.024550
# 7475   0.029630  0.239506  0.286420  0.059259  0.293210  0.023457  0.017901
# 8607   0.025859  0.256701  0.376537  0.155787  0.129927  0.010407  0.012299
# 9146   0.029155  0.217493  0.475219  0.096793  0.135277  0.007580  0.008163
# 7113   0.029690  0.363866  0.204675  0.123816  0.217309  0.003159  0.004422
# 15379  0.008135  0.308691  0.349793  0.229342  0.087912  0.002854  0.001284
# ...         ...       ...       ...       ...       ...       ...       ...
# 3107   0.045201  0.221261  0.407366  0.088449  0.171875  0.008371  0.011998
# 8256   0.013362  0.224187  0.491564  0.169659  0.078688  0.003644  0.002969
# 12750  0.016489  0.149980  0.647012  0.091940  0.069516  0.005540  0.004089
# 2032   0.046053  0.206579  0.342105  0.056579  0.189474  0.023684  0.034211
# 3941        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9785   0.033654  0.237179  0.416667  0.126603  0.134615  0.003205  0.016026
# 3284   0.016477  0.244191  0.458175  0.146177  0.114913  0.002535  0.002535
# 16842  0.036296  0.261481  0.314074  0.068148  0.230370  0.017037  0.014074
# 19120  0.030848  0.136247  0.512853  0.033419  0.159383  0.010283  0.035990
# 5370   0.017469  0.242248  0.474604  0.169777  0.075347  0.004069  0.003718
# 6912   0.017056  0.140934  0.668425  0.086849  0.065081  0.002693  0.002469
# 7125   0.061252  0.208094  0.365053  0.059885  0.210555  0.017501  0.018321
# 1924   0.025584  0.195412  0.496692  0.092633  0.114248  0.012351  0.013674
# 9413   0.045803  0.322326  0.221133  0.096932  0.238389  0.018534  0.015339
# 9441   0.015487  0.250737  0.394297  0.167896  0.147738  0.002704  0.004671
# 18123  0.029216  0.223108  0.422753  0.092961  0.165117  0.010181  0.020806
# 7465   0.010738  0.253445  0.466312  0.176090  0.081251  0.001425  0.001378
# 15243  0.025188  0.233083  0.447059  0.141176  0.109514  0.009396  0.008448
# 17223  0.021337  0.093883  0.692745  0.032717  0.086771  0.001422  0.014225
# 10498  0.026676  0.343629  0.170937  0.129344  0.284486  0.013163  0.008775
# 13896  0.040261  0.270528  0.311426  0.134468  0.186983  0.010980  0.011139
# 17336  0.041101  0.161765  0.365385  0.063725  0.180995  0.023002  0.044495
# 5779   0.006057  0.365157  0.252668  0.136141  0.235074  0.000577  0.001442
# 1854   0.047619  0.150632  0.510204  0.068027  0.094266  0.003887  0.007775
# 4156   0.034483  0.299672  0.266831  0.115558  0.212849  0.017036  0.010468
# 12427  0.017972  0.306162  0.258023  0.207317  0.179076  0.000642  0.002567
# 18743  0.031098  0.134111  0.550049  0.041788  0.109815  0.013605  0.017493
# 14521  0.037164  0.202218  0.460595  0.103115  0.140514  0.011326  0.010264
# 10292  0.025751  0.253219  0.402361  0.121245  0.172747  0.005365  0.002146
# 896    0.027027  0.231660  0.403475  0.073359  0.135135  0.021236  0.023166
#
#        flights  squawk_1  observations     type  label  type_code
# 11678     33.0       0.0         688.0     C208    NaN       97.0
# 7869      13.0       0.0         815.0     P28A    NaN      323.0
# 3019      14.0    4573.0        1024.0     T206    NaN      417.0
# 9612      17.0    2405.0        1257.0     PC12    NaN      356.0
# 7139      14.0    1200.0        3344.0     B58T    NaN       44.0
# 2123      24.0    1200.0        7118.0     C172    NaN       88.0
# 17621     53.0    1200.0       25056.0     PA24    NaN      342.0
# 2171      12.0    1200.0        2931.0     C180    NaN       90.0
# 16278      NaN       NaN           NaN      NaN    NaN        NaN
# 13836     26.0    1144.0        8551.0     TBM7    NaN      431.0
# 4073      47.0    1200.0       16507.0     RV12    NaN      375.0
# 83         7.0       0.0         570.0     C340    NaN      110.0
# 13419     87.0       0.0         771.0     C172    NaN       88.0
# 2231      19.0    7276.0        1497.0     PA11    NaN      338.0
# 17803     16.0       0.0        1086.0     BE36    NaN       54.0
# 9742      13.0    5633.0         977.0  unknown    NaN      454.0
# 11853     75.0       0.0        4957.0     BE20    NaN       48.0
# 7831      14.0    1200.0        4782.0  unknown    NaN      454.0
# 119        9.0    1733.0        2525.0     C501    NaN      119.0
# 10805    102.0       0.0        5608.0     PC12    NaN      356.0
# 17780      9.0       0.0         575.0     BE10    NaN       45.0
# 19092     11.0    1200.0        3187.0      RV7    NaN      380.0
# 993       17.0       0.0        9204.0     SR20    NaN      405.0
# 4341      48.0       0.0        2990.0     C55B    NaN      124.0
# 11781     36.0       0.0        1222.0     PA46    NaN      350.0
# 7475      13.0    1200.0        1620.0  unknown    NaN      454.0
# 8607      11.0    1352.0        3171.0     M20P    NaN      300.0
# 9146      39.0       0.0        1715.0     PC12    NaN      356.0
# 7113       8.0    1200.0        1583.0  unknown    NaN      454.0
# 15379     14.0       0.0        7007.0     M20P    NaN      300.0
# ...        ...       ...           ...      ...    ...        ...
# 3107      58.0       0.0        3584.0     EA50    NaN      191.0
# 8256      23.0    1200.0        7409.0  unknown    NaN      454.0
# 12750     23.0    1200.0        7581.0     C240    NaN      100.0
# 2032      34.0       0.0         760.0     C182    NaN       91.0
# 3941       NaN       NaN           NaN      NaN    NaN        NaN
# 9785      14.0       0.0         624.0     BE58    NaN       60.0
# 3284      18.0    1200.0        4734.0  unknown    NaN      454.0
# 16842     17.0     220.0        1350.0     C150    NaN       84.0
# 19120     35.0       0.0         778.0     BE36    NaN       54.0
# 5370      56.0       0.0       14254.0     C414    NaN      114.0
# 6912      24.0       0.0        8912.0  unknown    NaN      454.0
# 7125     101.0       0.0        3657.0     BE20    NaN       48.0
# 1924      10.0       0.0        2267.0     LNCE    NaN      293.0
# 9413      42.0    4611.0        4694.0     C82T    NaN      134.0
# 9441      28.0    1200.0        4068.0     M20P    NaN      300.0
# 18123     37.0    7625.0        2259.0     T206    NaN      417.0
# 7465      46.0    1200.0       21046.0     C310    NaN      106.0
# 15243     37.0    1200.0       12665.0      RV6    NaN      379.0
# 17223     17.0       0.0         703.0     SR22    NaN      406.0
# 10498     34.0    1200.0        5698.0     P28A    NaN      323.0
# 13896     39.0       0.0        6284.0     TBM7    NaN      431.0
# 17336     68.0    1200.0        2652.0     AS50    NaN       18.0
# 5779      10.0       0.0        3467.0     HXB2    NaN      263.0
# 1854      10.0       0.0        1029.0      RV7    NaN      380.0
# 4156      22.0    1200.0        4872.0     RV12    NaN      375.0
# 12427      6.0    1200.0        1558.0  unknown    NaN      454.0
# 18743     38.0       0.0        1029.0     C172    NaN       88.0
# 14521    103.0       0.0        8476.0     EA50    NaN      191.0
# 10292     11.0    2551.0         932.0     C182    NaN       91.0
# 896       19.0       0.0         518.0      MU2    NaN      312.0
#
# [200 rows x 38 columns]

# %% [markdown]
# # Questions

# %% [markdown]
# ### Question 1
#
# What kind of machine learning are we doing here, and why are we doing it?

# %%
# In this exercise, we trained and tested machine learning models to detect patterns in data and classify data based on 
## these patterns.

# %% [markdown]
# ### Question 2
#
# What are a few different ways you can deal with categorical data? Think about how we dealt with race in the reveal regression compared to how we dealt with type in this dataset.

# %%
# In the mortage analysis exercise, we used categorical data to predict bias. Here, we used categorical data to classify planes.

# %% [markdown]
# ### Question 3
#
# Every time we ran a machine learning algorithm on our dataset, we looked at feature importance.
#
# * When might it be important to explain what our model found important?
# * When might it not be important?

# %%
# Whichever classification model we choose, it is important to look at the factors/features based on which the model made 
## predictions.

# The interpretation of features is different for logistic regression and trees/forests. In a  logistic regression, 
## I would compare the odds-ratios of my independent variables to see which ones are the strongest predictors.
## The control variables are not as important, but it might be useful to check the effects they have, so we can re-think
## including/excluding them.

# In a decision tree, the features are important in understanding the patterns that the algorithm found, but the numbers
## don't mean much as they are only telling us which features consitute the largest share in the tree. They are key features
## but it does not mean that they have a correlation with the outcome variable.

# %% [markdown]
# ### Question 4
#
# Using words and not column names, describe what the machine learning algorithm found to be important when identifying surveillance planes.

# %%
# The decision tree and forest plots found the steer of the aircraft to be the strongest predictor of whether it was a 
## surveillance plane or not.

# %% [markdown]
# ### Question 5
#
# Why did we use test/train split when it would have been more effective to give our model all of the data from the start?

# %%
# To avoid over-fitting

# %% [markdown]
# ### Question 6
#
# Why did we use a random forest instead of a decision tree or logistic regression? Was there something about the data?

# %%
# To get a better accuracy rate

# %% [markdown]
# ### Question 7
#
# Why did we use probability instead of just looking for planes with a predicted value of 1? It seems like we should have just trusted the algorithm, right?

# %%
# To potentially determine our own cut-off instead of using the >0.5 cut off that the algorithm uses.

# %% [markdown]
# ### Question 8
#
# What if our random forest or input dataset were flawed? What would be the repercussions?

# %%
# Major - as the story makes important allegations against the government

# %% [markdown]
# ### Question 9
#
# The government could claim that we're threatening national security by publishing this paper as well as publishing this code - now anyone could look for planes that are surveilling them. What do you think?

# %%
# Yes, that is absolutely true. The story will have to be reviewed by experts on aircrafts, and the air force. The consequences
## will have to be considered.

# %% [markdown]
# ### Question 10
#
# We're using data from the past, but you can get real-time flight data from many services. Can you think of any uses for this algorithm using real-time instead of historical data?

# %%
# Real-time data can give us an imteractive story wherein readers can find out potential surveillance planes real-time. 
## However, I would refrain from doing so, as the risks are much higher. With historical data, one is only providing 
## information about surveillance planes, but by providing easy access to real time data, the story urges readers to take action.

# %% [markdown]
# ### Question 11
#
# This isn't a question, but if you look at `candidates.csv` and `candidates-annotates.csv` you can see how Buzzfeed did their research after finding a list of suspicious planes.

# %%
# Thank you!

# %% [markdown]
# #### The End!
