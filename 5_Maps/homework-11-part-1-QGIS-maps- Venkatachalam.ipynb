# %% [markdown]
# ## Homework 11 - Venkatachalam
# #### Date: 27-June-2019

# %% [markdown]
# ### Map 1 - Dot Map

# %% [markdown]
# ![map-1.png](attachment:map-1.png)

# %% [markdown]
# ### Map 2 - Bubble Map

# %% [markdown]
# ![map-2.png](attachment:map-2.png)

# %% [markdown]
# ### Map 3 - Colored Dot Map

# %% [markdown]
# ![map-3.png](attachment:map-3.png)

# %% [markdown]
# ### Map 4 - Colored Bubble Map

# %% [markdown]
# ![map-4.png](attachment:map-4.png)

# %% [markdown]
# ### Map 5 - Coal Only

# %% [markdown]
# ![map5.png](attachment:map5.png)

# %% [markdown]
# ### Map 6 - Coal Only

# %% [markdown]
# ![map-6.png](attachment:map-6.png)

# %% [markdown]
# ### Map 7 - Solar choropleth

# %% [markdown]
# ![map-7-solar-choropleth.png](attachment:map-7-solar-choropleth.png)

# %% [markdown]
# ### Map 8 - Coal choropleth

# %% [markdown]
# ![map-8-coal-choropleth.png](attachment:map-8-coal-choropleth.png)

# %% [markdown]
# ### Map 9 - Power output by state

# %% [markdown]
# ![map-9-power-output-by-state.png](attachment:map-9-power-output-by-state.png)

# %% [markdown]
# #### The End!
